# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib import cm, colors
from sklearn.decomposition import KernelPCA
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import MDS
from sklearn.manifold import TSNE

# %%
# https://stats.stackexchange.com/questions/256172/why-is-dimensionality-reduction-always-done-before-clustering
# https://stats.stackexchange.com/questions/584174/interpretation-of-low-variance-in-pca
# https://stats.stackexchange.com/questions/429026/advantage-disadvantage-of-pca-vs-kernel-pca

# %%
feb_vectors = np.load(".//data//arxiv test//feb//feb_inferred_vectors.npy")
feb_papers = np.load(".//data//arxiv test//feb//feb_good_papers.npy")

feb_results_df = pd.read_csv("lr_feb_results.csv")
feb_results_df.head()

feb_df = pd.DataFrame(feb_vectors)
feb_df["ea prob"] = feb_results_df["ea prob"]
feb_df["source"] = "feb"

feb_years = [int("20"+title[:2]) for title in feb_papers]
feb_df["year"] = feb_years

feb_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.168622 -0.132575 -0.111370 -0.016159 -0.147179 -0.052612 -0.259438
# 1 -0.852917 -0.098700 -0.168356  0.155176  0.341153  0.063643 -0.154522
# 2 -0.055933 -0.185382 -0.199830  0.257804 -0.257122  0.368190 -0.084500
# 3  0.226894 -0.075230 -0.149943 -0.087697  0.180333  0.788311  0.010205
# 4 -0.003768 -0.335108 -0.171022 -0.068785 -0.102779  0.028012 -0.279151
#
#           7         8         9  ...       593       594       595       596  \
# 0 -0.260758 -0.241815  0.303085  ... -0.195508  0.362219  0.230822 -0.229691
# 1 -0.091102 -0.012636  0.308401  ...  0.258261  0.302605 -0.413259  0.013836
# 2 -0.324122 -0.224946  0.328204  ...  0.185930  0.197679 -0.192635  0.012338
# 3  0.245074  0.149484 -0.005194  ...  0.230704  0.254560 -0.099013 -0.285573
# 4 -0.616968 -0.375763 -0.181762  ...  0.188640 -0.125718  0.295861 -0.004114
#
#         597       598       599   ea prob  source  year
# ...

# %%
fname = ".//data//model_dbow_vs_600_n_5_s_0_inferred_training_data.csv"
training_df = pd.read_csv(fname).drop("Unnamed: 0", axis=1)
training_df = training_df.drop(columns="label")

lr_training_probs = np.load("lr_training_probs.npy")

training_df["ea prob"] = lr_training_probs
training_df["source"] = "train"

train_bibs = pd.read_csv(".//data//training_bibs.csv")
train_years = train_bibs["bib"].str[:4].astype(int)
training_df["year"] = train_years

training_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.024851 -0.381951 -0.651674  0.553038  1.299930  1.031808  0.333705
# 1  0.388153  0.000402  0.285238 -1.093168 -0.517576 -0.442416  0.572925
# 2  0.570890 -0.482221 -0.214128 -0.549572 -0.095529  0.389266 -0.176438
# 3 -0.098389 -0.022716 -0.856276 -0.721896 -0.125313  0.093145  0.662419
# 4 -0.207901 -0.841178  0.095708  0.132864  0.298601  0.492365 -0.053234
#
#           7         8         9  ...       593       594       595       596  \
# 0 -0.101893  0.053647  0.222175  ...  0.379752  0.410750 -0.602648  0.904846
# 1 -0.000812 -0.088989  0.351440  ... -0.036528  0.238906 -0.149262  0.399019
# 2 -0.252203  0.049001 -0.112858  ... -0.015409  0.238097  0.032458  0.268519
# 3 -0.438362  0.227312  0.410582  ...  0.440777 -0.599077  0.119088 -0.006456
# 4  0.299751 -0.317690 -0.691285  ...  0.405798  0.046836  0.045763 -0.604552
#
#         597       598       599   ea prob  source  year
# ...

# %%
feb_df.columns = training_df.columns

vector_df = pd.concat([training_df, feb_df], axis=0)
vector_df =  training_df.copy()
vector_df = vector_df[vector_df["year"] >= 2000]
vector_df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.024851 -0.381951 -0.651674  0.553038  1.299930  1.031808  0.333705
# 1     0.388153  0.000402  0.285238 -1.093168 -0.517576 -0.442416  0.572925
# 2     0.570890 -0.482221 -0.214128 -0.549572 -0.095529  0.389266 -0.176438
# 3    -0.098389 -0.022716 -0.856276 -0.721896 -0.125313  0.093145  0.662419
# 4    -0.207901 -0.841178  0.095708  0.132864  0.298601  0.492365 -0.053234
# ...        ...       ...       ...       ...       ...       ...       ...
# 7558  0.223156 -0.606353 -0.480475 -0.363644 -0.130124 -0.009473 -0.368564
# 7559  1.322260 -0.030642  0.049319  0.549138  0.594312 -0.116567 -0.077711
# 7560 -0.713824  0.014754 -0.107428  0.229410  0.495667 -0.228321 -1.444375
# 7561 -0.652473 -0.063591 -0.153040 -0.505351 -0.107748  0.619319 -0.051542
# 7562  0.231518  0.503244 -0.391337  0.508180  0.248683  0.470101  0.524473
#
# ...

# %%
numeric_vectors = vector_df.iloc[:, :600]

plt.hist(numeric_vectors.values.flatten(), density=True)
plt.show()

# %%
feature1 = np.random.choice(range(numeric_vectors.shape[1]))
feature2 = np.random.choice(range(numeric_vectors.shape[1]))

plt.scatter(numeric_vectors.iloc[:,feature1], numeric_vectors.iloc[:,feature2], alpha=0.5)
plt.xlabel(f"Feature {feature1}")
plt.ylabel(f"Feature {feature2}")
plt.show()

# %%
plt.hist(vector_df["year"])
plt.show()

print(min(vector_df["year"]), max(vector_df["year"]), len(np.unique(vector_df["year"])))

plt.hist(vector_df["ea prob"])
plt.show()
# Out:
# 2000 2023 24

# %%
unique_years = np.unique(vector_df["year"])
prob_mean_by_year = vector_df.groupby("year").mean()["ea prob"]
prob_var_by_year = vector_df.groupby("year").mean()["ea prob"]

plt.errorbar(x=unique_years, y=prob_mean_by_year, yerr=prob_var_by_year, fmt="o")
plt.show()

np.corrcoef(vector_df["year"], vector_df["ea prob"])
# Out:
# array([[1.        , 0.47095252],
#        [0.47095252, 1.        ]])

# %%
all_vectors = vector_df.iloc[:, :600]
scaler = StandardScaler()
all_vectors = scaler.fit_transform(all_vectors)

# %%
# https://stats.stackexchange.com/questions/501226/if-my-explained-variance-is-low-in-my-pca-component-is-it-still-useful-for-cl

pca = PCA()
X_pca = pca.fit_transform(all_vectors)

print(pca.explained_variance_ratio_[:2])
# print(pca.singular_values_)

cmap = cm.get_cmap("viridis")

sc = plt.scatter(X_pca[:,0], X_pca[:,1], c=vector_df["ea prob"], cmap=cmap)

plt.colorbar(sc, label="EA Prob.")
plt.xlabel('PC 0')
plt.ylabel('PC 1')

plt.show()

sc = plt.scatter(X_pca[:,0], X_pca[:,1], c=vector_df["year"], cmap=cmap)

plt.colorbar(sc, label="Year")
plt.xlabel('PC 0')
plt.ylabel('PC 1')

plt.show()
# Out:
# [0.01095946 0.00750367]
# C:\Users\Nick\AppData\Local\Temp\ipykernel_7588\2275333369.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap("viridis")

# %%
# https://stats.stackexchange.com/questions/131142/how-to-choose-a-kernel-for-kernel-pca

gamma = 1.25 * (1/np.shape(all_vectors)[1])
pca = KernelPCA(kernel='rbf')
X_pca = pca.fit_transform(all_vectors)

print(pca.eigenvalues_)
# print(pca.singular_values_)

cmap = cm.get_cmap("viridis")

sc = plt.scatter(X_pca[:,0], X_pca[:,1], c=vector_df["ea prob"], cmap=cmap)

plt.colorbar(sc, label="EA Prob.")
plt.xlabel('PC 0')
plt.ylabel('PC 1')

plt.show()

sc = plt.scatter(X_pca[:,0], X_pca[:,1], c=vector_df["year"], cmap=cmap)

plt.colorbar(sc, label="Year")
plt.xlabel('PC 0')
plt.ylabel('PC 1')

plt.show()
# Out:
# [4.77513418e+01 2.27947593e+01 1.62459842e+01 ... 4.79939397e-03
#  4.65563646e-03 4.52404650e-03]
# C:\Users\Nick\AppData\Local\Temp\ipykernel_7588\1876895801.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap("viridis")

# %%
all_vectors.shape[1]
# Out:
# 600

# %%
# https://stackoverflow.com/questions/36566844/pca-projection-and-reconstruction-in-scikit-learn
for i in [1]:
    gamma = i * (1.0/all_vectors.shape[1])
    
    pca = KernelPCA(kernel='rbf', gamma=gamma, fit_inverse_transform=True)
    X_pca = pca.fit_transform(all_vectors)

    X_projected = pca.inverse_transform(X_pca)

    loss = np.sum((all_vectors - X_projected) ** 2, axis=1).mean()
    print(i, loss)
    
# 0.1 599.0067038464982
# 0.5 588.604746376879
# 0.75 583.9001505693393
# 1 581.6061163223749
# 1.25 581.0359822591566
# 1.5 581.4402140416967
# 1.75 582.2579052456407
# 2 583.1338615187789
# Out:
# 1 581.6061163223749

# %%
# https://distill.pub/2016/misread-tsne/
# https://stats.stackexchange.com/questions/222912/how-to-determine-parameters-for-t-sne-for-reducing-dimensions
# https://arxiv.org/pdf/1708.03229.pdf

for perp in [5, 25, 50, 0.05*all_vectors.shape[0], 0.5*all_vectors.shape[0]]:
    tsne = TSNE(perplexity=perp, learning_rate="auto", init="pca", n_iter=10000, verbose=0)
    X_tsne = tsne.fit_transform(all_vectors)

    cmap = cm.get_cmap("viridis")

    sc = plt.scatter(X_tsne[:,0], X_tsne[:,1], c=vector_df["ea prob"], cmap=cmap)

    plt.colorbar(sc, label="EA Prob.")
    plt.xlabel('Embedding 0')
    plt.ylabel('Embedding 1')
    plt.title(f"Perplexity={perp}")
    plt.show()

    sc = plt.scatter(X_tsne[:,0], X_tsne[:,1], c=vector_df["year"], cmap=cmap)

    plt.colorbar(sc, label="Year")
    plt.xlabel('Embedding 0')
    plt.ylabel('Embedding 1')
    plt.title(f"Perplexity={perp}")
    plt.show()
# Out:
# C:\Users\Nick\AppData\Local\Temp\ipykernel_7588\2125685374.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap("viridis")
# C:\Users\Nick\AppData\Local\Temp\ipykernel_7588\2125685374.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap("viridis")
# C:\Users\Nick\AppData\Local\Temp\ipykernel_7588\2125685374.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap("viridis")
# ...
