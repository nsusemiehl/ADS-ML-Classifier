# %%
import pandas as pd
import ads
import requests
import PyPDF2
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
import numpy as np
import random
import re
import urllib3
import time
from requests.adapters import TimeoutSauce
import urllib, urllib.request    
from datetime import datetime
import feedparser
try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen
    

from urllib.parse import urlencode, quote_plus

# %% [markdown]
# ## ADS

# %%
ADS_DEV_KEY = "FEbkvybqpxpJQdeF5E8btv7KvfFM4Eh5ezHV7Z8S"
ads.config.token = "FEbkvybqpxpJQdeF5E8btv7KvfFM4Eh5ezHV7Z8S"

# %%
# https://github.com/adsabs/adsabs-dev-api/blob/master/API_documentation_Python/Search_API_Python.ipynb
# https://ui.adsabs.harvard.edu/help/search/comprehensive-solr-term-list
# https://solr.apache.org/guide/6_6/working-with-dates.html

# entdate: indicates when the record was first entered into our system
# update_timestamp: indicates when the record was updated in our system (small things such a new read/download will trigger an update)
# metadata_mtime: last time when the metadata (e.g., title, abstract) was modified
# nonbib_mtime: time when the other data (e.g., refereed, total citations) was modified
# fulltext_mtime: last time when the full text was modified
# orcid_mtime: last time when the ORCID claims were modified
# metrics_mtime: last time when metrics (e.g., historical reads, citations) were modified

# %%
start_month = "04"
start_year = "2023"

end_month = "04"
end_year = "2023"

for d in range(1, 30):
    start_day = d
    if int(start_day) < 10:
        start_day = f"0{start_day}"
    end_day = d + 1
    if int(end_day) < 10:
        end_day = f"0{end_day}"
    
#     encoded_query = urlencode({"q": f"metadata_mtime:[{start_year}-{start_month}-{start_day}T00\:00\:00.000Z TO {end_year}-{end_month}-{end_day}T00\:00\:00.000Z]",
#                            "fl": "bibcode, title, identifier",
#                            "fq": "database:astronomy",
#                            "rows": 9999})
    
    encoded_query = urlencode({"q": f"entdate:[{start_year}-{start_month}-{start_day} TO {end_year}-{end_month}-{end_day}]", 
                           "fl": "bibcode, identifier, title", 
                           "fq": "database:astronomy", 
                           "rows": 9999})

    results = requests.get("https://api.adsabs.harvard.edu/v1/search/query?{}".format(encoded_query), headers={'Authorization': 'Bearer ' + ADS_DEV_KEY})
    ads_bibs = [paper['bibcode'] for paper in results.json()["response"]["docs"]]
    print(f"{start_day}-{end_day}: {len(ads_bibs)}")
    

# april
# metadata_mtime, "fq": "database:astronomy"
# 01-02: 8
# 02-03: 1802
# 03-04: 0
# 04-05: 0
# 05-06: 0
# 06-07: 38
# 07-08: 0
# 08-09: 0
# 09-10: 0
# 10-11: 0
# 11-12: 0
# 12-13: 0
# 13-14: 1419
# 14-15: 0
# 15-16: 143
# 16-17: 0
# 17-18: 0
# 18-19: 0
# 19-20: 0
# 20-21: 0
# 21-22: 0
# 22-23: 0
# 23-24: 0
# 24-25: 0
# 25-26: 0
# 26-27: 0
# 27-28: 0
# 28-29: 0
# 29-30: 0


# metadata_mtime, "fq": "database:astronomy, property:article, property:(refereed OR eprint_openaccess)"
# 01-02: 8
# 02-03: 1452
# 03-04: 0
# 04-05: 0
# 05-06: 0
# 06-07: 38
# 07-08: 0
# 08-09: 0
# 09-10: 0
# 10-11: 0
# 11-12: 0
# 12-13: 0
# 13-14: 1104
# 14-15: 0
# 15-16: 143
# 16-17: 0
# 17-18: 0
# 18-19: 0
# 19-20: 0
# 20-21: 0
# 21-22: 0
# 22-23: 0
# 23-24: 0
# 24-25: 0
# 25-26: 0
# 26-27: 0
# 27-28: 0
# 28-29: 0
# 29-30: 0
# 30-31: 55

# metadata_mtime, "fq": "database:astronomy, property:article, property:(refereed OR eprint_openaccess), abs:(planet OR exoplanet OR extrasolar OR brown OR Jupiter OR Neptune OR TESS OR K2 OR Kepler OR HD OR GJ or HIP OR TIC OR TOI OR KOI OR 2MASS OR OGLE OR KMT OR EPIC OR MOA -asteroid)"
# 01-02: 0
# 02-03: 264
# 03-04: 0
# 04-05: 0
# 05-06: 0
# 06-07: 2
# 07-08: 0
# 08-09: 0
# 09-10: 0
# 10-11: 0
# 11-12: 0
# 12-13: 0
# 13-14: 153
# 14-15: 0
# 15-16: 15
# 16-17: 0
# 17-18: 0
# 18-19: 0
# 19-20: 0
# 20-21: 0
# 21-22: 0
# 22-23: 0
# 23-24: 0
# 24-25: 0
# 25-26: 0
# 26-27: 0
# 27-28: 0
# 28-29: 0
# 29-30: 0


# entdate, "fq": "database:astronomy"
# 01-02: 1052
# 02-03: 55
# 03-04: 92
# 04-05: 116
# 05-06: 63
# 06-07: 46
# 07-08: 0
# 08-09: 794
# 09-10: 30
# 10-11: 66
# 11-12: 99
# 12-13: 51
# 13-14: 59
# 14-15: 0
# 15-16: 2000
# 16-17: 56
# 17-18: 108
# 18-19: 116
# 19-20: 52
# 20-21: 61
# 21-22: 0
# 22-23: 1346
# 23-24: 37
# 24-25: 74
# 25-26: 912
# 26-27: 70
# 27-28: 62
# 28-29: 0
# 29-30: 1127


# entdate, "fq": "database:astronomy, property:article, property:(refereed OR eprint_openaccess)"
# 01-02: 806
# 02-03: 55
# 03-04: 92
# 04-05: 116
# 05-06: 63
# 06-07: 46
# 07-08: 0
# 08-09: 451
# 09-10: 30
# 10-11: 66
# 11-12: 99
# 12-13: 51
# 13-14: 59
# 14-15: 0
# 15-16: 592
# 16-17: 56
# 17-18: 108
# 18-19: 116
# 19-20: 52
# 20-21: 61
# 21-22: 0
# 22-23: 522
# 23-24: 37
# 24-25: 74
# 25-26: 912
# 26-27: 70
# 27-28: 62
# 28-29: 0
# 29-30: 813


# entdate, "fq": "database:astronomy, property:article, property:(refereed OR eprint_openaccess), abs:(planet OR exoplanet OR extrasolar OR brown OR Jupiter OR Neptune OR TESS OR K2 OR Kepler OR HD OR GJ or HIP OR TIC OR TOI OR KOI OR 2MASS OR OGLE OR KMT OR EPIC OR MOA -asteroid)", 
# 01-02: 83
# 02-03: 9
# 03-04: 5
# 04-05: 8
# 05-06: 7
# 06-07: 8
# 07-08: 0
# 08-09: 66
# 09-10: 6
# 10-11: 8
# 11-12: 4
# 12-13: 5
# 13-14: 5
# 14-15: 0
# 15-16: 100
# 16-17: 4
# 17-18: 11
# 18-19: 9
# 19-20: 6
# 20-21: 4
# 21-22: 0
# 22-23: 79
# 23-24: 3
# 24-25: 6
# 25-26: 21
# 26-27: 8
# 27-28: 7
# 28-29: 0
# 29-30: 121
# Out:
# 01-02: 1052
# 02-03: 55
# 03-04: 92
# 04-05: 116
# 05-06: 63
# 06-07: 46
# 07-08: 0
# 08-09: 794
# 09-10: 30
# 10-11: 66
# 11-12: 99
# 12-13: 51
# 13-14: 59
# 14-15: 0
# 15-16: 2000
# 16-17: 56
# 17-18: 108
# 18-19: 116
# 19-20: 52
# 20-21: 61
# 21-22: 0
# 22-23: 1346
# 23-24: 37
# 24-25: 74
# 25-26: 912
# 26-27: 70
# 27-28: 62
# 28-29: 0
# 29-30: 1127

# %%
print(results.json())
# Out:
# {'responseHeader': {'status': 0, 'QTime': 20, 'params': {'q': 'metadata_mtime:[2023-1-30T00\\:00\\:00.000Z TO 2023-1-31T00\\:00\\:00.000Z]', 'fl': 'bibcode,title,identifier', 'start': '0', 'internal_logging_params': 'X-Amzn-Trace-Id=Root=1-64778dc8-136a5d4c1b39a19b42ae1f73', 'fq': 'database:astronomy, property:article, property:(refereed OR eprint_openaccess), abs:(planet OR exoplanet OR extrasolar OR brown OR Jupiter OR Neptune OR TESS OR K2 OR Kepler OR HD OR GJ or HIP OR TIC OR TOI OR KOI OR 2MASS OR OGLE OR KMT OR EPIC OR MOA -asteroid)', 'rows': '2000', 'wt': 'json'}}, 'response': {'numFound': 0, 'start': 0, 'docs': []}}

# %%
encoded_query = urlencode({"q": "metadata_mtime:[2023-05-22T00\:00\:00.000Z TO 2023-05-23T00\:00\:00.000Z]",
                           "fl": "bibcode, title, identifier",
                           "fq": "database:astronomy",
                           "rows": 9999})

# entdate:[2023-04-18 TO 2023-04-20]
# update_timestamp:[2023-05-03T22\:00\:00.000Z TO 2023-05-04T12\:00\:00.000Z]

results = requests.get("https://api.adsabs.harvard.edu/v1/search/bigquery?{}".format(encoded_query), \
                       headers={'Authorization': 'Bearer ' + ADS_DEV_KEY})

print(results.json())
# Out:
# {'responseHeader': {'status': 0, 'QTime': 16, 'params': {'q': 'metadata_mtime:[2023-05-22T00\\:00\\:00.000Z TO 2023-05-23T00\\:00\\:00.000Z]', 'fl': 'bibcode,title,identifier', 'start': '0', 'internal_logging_params': 'X-Amzn-Trace-Id=Root=1-64777c7d-4e6682e33b0b713d59b0414f', 'fq': 'database:astronomy', 'rows': '2000', 'wt': 'json'}}, 'response': {'numFound': 339, 'start': 0, 'docs': [{'bibcode': '2022zndo...6788444T', 'identifier': ['2022zndo...6788444T', '10.5281/zenodo.6788444'], 'title': ['AMReX-Codes/amrex: AMReX 22.07']}, {'bibcode': '2023zndo...7790123T', 'identifier': ['2023zndo...7790123T', '10.5281/zenodo.7790123'], 'title': ['AMReX-Codes/amrex: AMReX 23.04']}, {'bibcode': '2019zndo...3379043E', 'identifier': ['2019zndo...3379043E', '10.5281/zenodo.3379043'], 'title': ['CMAQ']}, {'bibcode': '2018zndo...1412743B', 'identifier': ['2018zndo...1412743B', '10.5281/zenodo.1412743'], 'title': ['Keplergo/Lightkurve: V1.0B14']}, {'bibcode': '2015zndo...1079909R', 'identifier': ['2015zndo...1079909R', '10.5281/zenodo.1079909'], 'title': ['Cmaqv5.1']}, {'bibcode': '2016zndo.....55595E', 'identifier': ['2016zndo.....55595E', '10.5281/zenodo.55595'], 'title': ['Pygsti: Version 0.9.1 Beta']}, {'bibcode': '2021zndo...5546759E', 'identifier': ['2021zndo...5546759E', '10.5281/zenodo.5546759'], 'title': ['pyGSTio/pyGSTi: Version 0.9.10']}, {'bibcode': '2020zndo...3903176F', 'identifier': ['2020zndo...3903176F', '10.5281/zenodo.3903176'], 'title': ['Silmathoron/NNGT: NNGT 2.0: full frontend for simple graphs, unified graph analysis']}, {'bibcode': '2019zndo...2650296J', 'identifier': ['2019zndo...2650296J', '10.5281/zenodo.2650296'], 'title': ['pyxem/pyxem: pyXem 0.7.1']}, {'bibcode': '2020zndo...3831473J', 'identifier': ['2020zndo...3831473J', '10.5281/zenodo.3831473'], 'title': ['pyxem/pyxem: pyxem 0.11.0']}, {'bibcode': '2019zndo...3530201S', 'identifier': ['2019zndo...3530201S', '10.5281/zenodo.3530201'], 'title': ['euratom-software/calcam: Calcam v2.4']}, {'bibcode': '2018zndo...2389481S', 'identifier': ['2018zndo...2389481S', '10.5281/zenodo.2389481'], 'title': ['Calcam']}, {'bibcode': '2019zndo...3435774D', 'identifier': ['2019zndo...3435774D', '10.5281/zenodo.3435774'], 'title': ['tqdm: A fast, Extensible Progress Bar for Python and CLI']}, {'bibcode': '2021zndo...5363443T', 'identifier': ['2021zndo...5363443T', '10.5281/zenodo.5363443'], 'title': ['AMReX-Codes/amrex: AMReX 21.09']}, {'bibcode': '2018zndo...1251290D', 'identifier': ['2018zndo...1251290D', '10.5281/zenodo.1251290'], 'title': ['Tqdm/Tqdm: Tqdm V4.23.4 Stable']}, {'bibcode': '2021zndo...5109730D', 'identifier': ['2021zndo...5109730D', '10.5281/zenodo.5109730'], 'title': ['tqdm: A fast, Extensible Progress Bar for Python and CLI']}, {'bibcode': '2019zndo...2611871B', 'identifier': ['2019zndo...2611871B', '10.5281/zenodo.2611871'], 'title': ['KeplerGO/lightkurve: Lightkurve v1.0b30']}, {'bibcode': '2023zndo...7794125A', 'identifier': ['2023zndo...7794125A', '10.5281/zenodo.7794125'], 'title': ['Sound Dynamic Deadlock Prediction in Linear Time']}, {'bibcode': '2016zndo....163867D', 'identifier': ['2016zndo....163867D', '10.5281/zenodo.163867'], 'title': ['Tqdm/Tqdm: Tqdm V4.9.0 Stable']}, {'bibcode': '2022zndo...6662839K', 'identifier': ['2022zndo...6662839K', '10.5281/zenodo.6662839'], 'title': ['tardis-sn/tardis: TARDIS v2022.06.19']}, {'bibcode': '2019zndo...3358046T', 'identifier': ['2019zndo...3358046T', '10.5281/zenodo.3358046'], 'title': ['AMReX-Codes/amrex: AMReX 19.08']}, {'bibcode': '2022zndo...7017973Y', 'identifier': ['2022zndo...7017973Y', '10.5281/zenodo.7017973'], 'title': ['amospktai/geos-chem-ecophysiology: GEOS-Chem v12.2.0 with Ecophysiology Module']}, {'bibcode': '2014zndo...1079898R', 'identifier': ['2014zndo...1079898R', '10.5281/zenodo.1079898'], 'title': ['Cmaqv5.0.2']}, {'bibcode': '2022zndo...6555235K', 'identifier': ['2022zndo...6555235K', '10.5281/zenodo.6555235'], 'title': ['Khurana Jupiter Current Sheet Structure Model 2022']}, {'bibcod ...

# %%
encoded_query = urlencode({"q": f"entdate:[2023-03-01 TO 2023-03-02]", 
                           "fl": "bibcode, identifier, title", 
                           "fq": "database:astronomy, property:article, property:(refereed OR eprint_openaccess)", 
                           "rows": 9999})

results = requests.get("https://api.adsabs.harvard.edu/v1/search/bigquery?{}".format(encoded_query), \
                       headers={'Authorization': 'Bearer ' + ADS_DEV_KEY})

ads_bibs = [paper['bibcode'] for paper in results.json()["response"]["docs"]]
# results.json()
print(len(ads_bibs))
# Out:
# {'responseHeader': {'status': 0, 'QTime': 284, 'params': {'q': 'entdate:[2023-03-01 TO 2023-03-02]', 'fl': 'bibcode,identifier,title', 'start': '0', 'internal_logging_params': 'X-Amzn-Trace-Id=Root=1-64777c1f-2ad4d88a04265cbf2875ea0a', 'fq': 'database:astronomy, property:article, property:(refereed OR eprint_openaccess)', 'rows': '2000', 'wt': 'json'}}, 'response': {'numFound': 44, 'start': 0, 'docs': [{'bibcode': '2023arXiv230300306B', 'identifier': ['arXiv:2303.00306', '10.48550/arXiv.2303.00306', '2023arXiv230300306B'], 'title': ['A massive interacting galaxy 525 million years after the Big Bang']}, {'bibcode': '2023arXiv230300410S', 'identifier': ['2023arXiv230300410S', '10.48550/arXiv.2303.00410', 'arXiv:2303.00410'], 'title': ['JWST/NIRSpec Measurements of the Relationships Between Nebular Emission-line Ratios and Stellar Mass at z~3-6']}, {'bibcode': '2023arXiv230300453E', 'identifier': ['2023arXiv230300453E', 'arXiv:2303.00453', '10.48550/arXiv.2303.00453'], 'title': ['Advances in Optical / Infrared Interferometry']}, {'bibcode': '2023arXiv230300009L', 'identifier': ['10.48550/arXiv.2303.00009', '2023arXiv230300009L', 'arXiv:2303.00009'], 'title': ['JWST-TST Proper Motions: I. High-Precision NIRISS Calibration and Large Magellanic Cloud Kinematics']}, {'bibcode': '2023arXiv230300008D', 'identifier': ['2023arXiv230300008D', '10.48550/arXiv.2303.00008', 'arXiv:2303.00008'], 'title': ['A stellar halo walks into a bar: creation of substructure from a smooth distribution function']}, {'bibcode': '2023arXiv230300467N', 'identifier': ['10.48550/arXiv.2303.00467', '2023arXiv230300467N', 'arXiv:2303.00467'], 'title': ['Gaia colour-magnitude diagrams of young open clusters: Identification in the UBC catalogue and a comparison of manual and automated analysis']}, {'bibcode': '2023arXiv230300016F', 'identifier': ['arXiv:2303.00016', '10.48550/arXiv.2303.00016', '2023arXiv230300016F'], 'title': ['The metal-weak Milky Way stellar disk hidden in the Gaia-Sausage-Enceladus debris: the APOGEE DR17 view']}, {'bibcode': '2023arXiv230300441X', 'identifier': ['2023arXiv230300441X', '10.48550/arXiv.2303.00441', 'arXiv:2303.00441'], 'title': ['On the Satellite Plane Problem']}, {'bibcode': '2023arXiv230300384Z', 'identifier': ['2023arXiv230300384Z', 'arXiv:2303.00384', '10.48550/arXiv.2303.00384'], 'title': ['Misaligned gas accretion as a formation pathway of S0 galaxies']}, {'bibcode': '2023arXiv230300746G', 'identifier': ['arXiv:2303.00746', '2023arXiv230300746G', '10.48550/arXiv.2303.00746'], 'title': ['Canonical Hubble-Tension-Resolving Early Dark Energy Cosmologies are Inconsistent with the Lyman-$\\alpha$ Forest']}, {'bibcode': '2023arXiv230300063D', 'identifier': ['2023arXiv230300063D', '10.48550/arXiv.2303.00063', 'arXiv:2303.00063'], 'title': ['New chondritic bodies identified in eight oxygen-bearing white dwarfs']}, {'bibcode': '2023arXiv230300010S', 'identifier': ['10.48550/arXiv.2303.00010', '2023arXiv230300010S', 'arXiv:2303.00010'], 'title': ['Direct detection of supernova progenitor stars with ZTF and LSST']}, {'bibcode': '2023arXiv230300468S', 'identifier': ['arXiv:2303.00468', '10.48550/arXiv.2303.00468', '2023arXiv230300468S'], 'title': ['Pressure anisotropy and viscous heating in weakly collisional plasma turbulence']}, {'bibcode': '2023arXiv230300084R', 'identifier': ['2023arXiv230300084R', 'arXiv:2303.00084', '10.48550/arXiv.2303.00084'], 'title': ['Spin evolution of Venus-like planets subjected to gravitational and thermal tides']}, {'bibcode': '2023arXiv230300370Z', 'identifier': ['2023arXiv230300370Z', '10.48550/arXiv.2303.00370', 'arXiv:2303.00370'], 'title': ['Application of Deep Learning Methods for Distinguishing Gamma-Ray Bursts from Fermi/GBM TTE Data']}, {'bibcode': '2023arXiv230300056R', 'identifier': ['2023arXiv230300056R', 'arXiv:2303.00056', '10.48550/arXiv.2303.00056'], 'title': ['The K-band highest-resolution images of the Mira star R Car with GRAVITY-VLTI']}, {'bibcode': '2023arXiv230300508R', 'identifie ...

# %%
results.json()
# Out:
# {'responseHeader': {'status': 0,
#   'QTime': 331,
#   'params': {'q': 'entdate:[2023-03-01 TO 2023-03-02]',
#    'fl': 'bibcode,identifier,title',
#    'start': '0',
#    'internal_logging_params': 'X-Amzn-Trace-Id=Root=1-64777ba8-6cdd8b58056ffd9f6c675c9c',
#    'fq': 'database:astronomy, property:article, property:(refereed OR eprint_openaccess)',
#    'rows': '2000',
#    'wt': 'json'}},
#  'response': {'numFound': 44,
#   'start': 0,
#   'docs': [{'bibcode': '2023arXiv230300306B',
#     'identifier': ['arXiv:2303.00306',
#      '10.48550/arXiv.2303.00306',
#      '2023arXiv230300306B'],
#     'title': ['A massive interacting galaxy 525 million years after the Big Bang']},
#    {'bibcode': '2023arXiv230300410S',
#     'identifier': ['2023arXiv230300410S',
#      '10.48550/arXiv.2303.00410',
#      'arXiv:2303.00410'],
#     'title': ['JWST/NIRSpec Measurements of the Relationships Between Nebular Emission-line Ratios and Stellar Mass at z~3-6']},
#    {'bibcode': '2023arXiv230300453E',
#     'identifier': ['2023arXiv230300453E',
#      'arXiv:2303.00453',
#      '10.48550/arXiv.2303.00453'],
#     'title': ['Advances in Optical / Infrared Interferometry']},
#    {'bibcode': '2023arXiv230300009L',
#     'identifier': ['10.48550/arXiv.2303.00009',
#      '2023arXiv230300009L',
#      'arXiv:2303.00009'],
#     'title': ['JWST-TST Proper Motions: I. High-Precision NIRISS Calibration and Large Magellanic Cloud Kinematics']},
#    {'bibcode': '2023arXiv230300008D',
#     'identifier': ['2023arXiv230300008D',
#      '10.48550/arXiv.2303.00008',
#      'arXiv:2303.00008'],
#     'title': ['A stellar halo walks into a bar: creation of substructure from a smooth distribution function']},
#    {'bibcode': '2023arXiv230300467N',
#     'identifier': ['10.48550/arXiv.2303.00467',
#      '2023arXiv230300467N',
#      'arXiv:2303.00467'],
#     'title': ['Gaia colour-magnitude diagrams of young open clusters: Identification in the UBC catalogue and a comparison of manual and automated analysis']},
#    {'bibcode': '2023arXiv230300016F',
#     'identifier': ['arXiv:2303.00016',
#      '10.48550/arXiv.2303.00016',
#      '2023arXiv230300016F'],
#     'title': ['The metal-weak Milky Way stellar disk hidden in the Gaia-Sausage-Enceladus debris: the APOGEE DR17 view']},
#    {'bibcode': '2023arXiv230300441X',
#     'identifier': ['2023arXiv230300441X',
#      '10.48550/arXiv.2303.00441',
#      'arXiv:2303.00441'],
#     'title': ['On the Satellite Plane Problem']},
#    {'bibcode': '2023arXiv230300384Z',
#     'identifier': ['2023arXiv230300384Z',
#      'arXiv:2303.00384',
#      '10.48550/arXiv.2303.00384'],
#     'title': ['Misaligned gas accretion as a formation pathway of S0 galaxies']},
#    {'bibcode': '2023arXiv230300746G',
#     'identifier': ['arXiv:2303.00746',
#      '2023arXiv230300746G',
#      '10.48550/arXiv.2303.00746'],
#     'title': ['Canonical Hubble-Tension-Resolving Early Dark Energy Cosmologies are Inconsistent with the Lyman-$\\alpha$ Forest']},
#    {'bibcode': '2023arXiv230300063D',
#     'identifier': ['2023arXiv230300063D',
#      '10.48550/arXiv.2303.00063',
#      'arXiv:2303.00063'],
#     'title': ['New chondritic bodies identified in eight oxygen-bearing white dwarfs']},
#    {'bibcode': '2023arXiv230300010S',
#     'identifier': ['10.48550/arXiv.2303.00010',
#      '2023arXiv230300010S',
#      'arXiv:2303.00010'],
#     'title': ['Direct detection of supernova progenitor stars with ZTF and LSST']},
#    {'bibcode': '2023arXiv230300468S',
#     'identifier': ['arXiv:2303.00468',
#      '10.48550/arXiv.2303.00468',
#      '2023arXiv230300468S'],
#     'title': ['Pressure anisotropy and viscous heating in weakly collisional plasma turbulence']},
#    {'bibcode': '2023arXiv230300084R',
#     'identifier': ['2023arXiv230300084R',
#      'arXiv:2303.00084',
#      '10.48550/arXiv.2303.00084'],
#     'title': ['Spin evolution of Venus-like planets subjected to gravitational and thermal tides']},
#    {'bibcode': '2023arXiv230300370Z',
#     'identifier': ['2023arXiv230300370Z',
#      '10.48550/arXiv.2303.00370',
#      'arXiv:2303.00370'],
#     'title': ['Application of Deep Learning Methods for Distinguishing Gamma-Ray Bursts from Fermi/GBM TTE Data']},
#    {'bibcode': '2023arXiv230300056R',
#     'identifier': ['2023arXiv230300056R',
#      'arXiv:2303.00056',
#      '10.48550/arXiv.2303.00056'],
#     'title': ['The K-band highest-resolution images of the Mira star R Car with GRAVITY-VLTI']},
#    {'bibcode': '2023arXiv230300508R',
#     'identifier': ['arXiv:2303.00508',
#      '10.48550/arXiv.2303.00508',
#      '2023arXiv230300508R'],
#     'title': ['Surrogate forward models for population inference on compact binary mergers']},
#    {'bibcode': '2023arXiv230300005H',
#     'identifier': ['arXiv:2303.00005',
#      '2023arXiv230300005H',
#      '10.48550/arXiv.2303.00005'],
#     'title': ['Benchmarks and Explanations for Deep Learning Estimates of X-ray Galaxy Cluster Masses']},
#    {'bibcode': '2023arXiv230300015S',
#     'identifier': ['10.48550/arXiv.2303.00015',
#      'arXiv:2303.00015',
#      '2023arXiv230300015S'],
#     'title': ['LISA Constraints on an Intermediate-Mass Black Hole in the Galactic Centre']},
#    {'bibcode': '2023arXiv230300751T',
#     'identifier': ['2023arXiv230300751T',
#      '10.48550/arXiv.2303.00751',
#      'arXiv:2303.00751'],
#     'title': ['Clumpy Structures within the Turbulent Primordial Cloud']},
#    {'bibcode': '2023arXiv230300060D',
#     'identifier': ['10.48550/arXiv.2303.00060',
#      '2023arXiv230300060D',
#      'arXiv:2303.00060'],
#     'title': ['Uncertainties in the 12C+12C reaction rate and their impact on the composition of ultra-massive WDs']},
#    {'bibcode': '2023arXiv230300034B',
#     'identifier': ['arXiv:2303.00034',
#      '10.48550/arXiv.2303.00034',
#      '2023arXiv230300034B'],
#     'title': ['A Comprehensive Perturbative Formalism for Phase Mixing in Perturbed Disks. II. Phase Spirals in an Inhomogeneous Disk Galaxy with a Non-responsive Dark Matter Halo']},
#    {'bibcode': '2023arXiv230300670L',
#     'identifier': ['arXiv:2303.00670',
#      '10.48550/arXiv.2303.00670',
#      '2023arXiv230300670L'],
#     'title': ['Lunar impact flash results and space surveillance activities at Kryoneri Observatory']},
#    {'bibcode': '2023arXiv230300013T',
#     'identifier': ['2023arXiv230300013T',
#      'arXiv:2303.00013',
#      '10.48550/arXiv.2303.00013'],
#     'title': ['What neutron stars tell about the hadron-quark phase transition: a Bayesian study']},
#    {'bibcode': '2023arXiv230300038T',
#     'identifier': ['2023arXiv230300038T',
#      'arXiv:2303.00038',
#      '10.48550/arXiv.2303.00038'],
#     'title': ['Consistent cosmological structure formation on all scales in relativistic extensions of MOND']},
#    {'bibcode': '2023arXiv230300600P',
#     'identifier': ['2023arXiv230300600P',
#      'arXiv:2303.00600',
#      '10.48550/arXiv.2303.00600'],
#     'title': ['The $H_0$ tension alleviated through ultra-light primordial black holes: an information insight through gravitational waves']},
#    {'bibcode': '2023arXiv230300698Z',
#     'identifier': ['2023arXiv230300698Z',
#      'arXiv:2303.00698',
#      '10.48550/arXiv.2303.00698'],
#     'title': ['Cross calibration of gamma-ray detectors (GRD) of GECAM-C']},
#    {'bibcode': '2023arXiv230300537Z',
#     'identifier': ['2023arXiv230300537Z',
#      '10.48550/arXiv.2303.00537',
#      'arXiv:2303.00537'],
#     'title': ['The performance of SiPM-based gamma-ray detector (GRD) of GECAM-C']},
#    {'bibcode': '2023arXiv230300687Z',
#     'identifier': ['10.48550/arXiv.2303.00687',
#      '2023arXiv230300687Z',
#      'arXiv:2303.00687'],
#     'title': ['Ground calibration of Gamma-Ray Detectors of GECAM-C']},
#    {'bibcode': '2023arXiv230300339T',
#     'identifier': ['10.48550/arXiv.2303.00339',
#      'arXiv:2303.00339',
#      '2023arXiv230300339T'],
#     'title': ['In-orbit Performance of ME onboard Insight-HXMT in the first 5 years']},
#    {'bibcode': '2023arXiv230300412L',
#     'identifier': ['2023arXiv230300412L',
#      '10.48550/arXiv.2303.00412',
#      'arXiv:2303.00412'],
#     'title': ['Validating Monte Carlo simulations for an analysis chain in H.E.S.S']},
#    {'bibcode': '2023arXiv230300341K',
#     'identifier': ['arXiv:2303.00341',
#      '2023arXiv230300341K',
#      '10.48550/arXiv.2303.00341'],
#     'title': ['Response to criticism on "Ruling Out Primordial Black Hole Formation From Single-Field Inflation": A note on bispectrum and one-loop correction in single-field inflation with primordial black hole formation']},
#    {'bibcode': '2023arXiv230300661S',
#     'identifier': ['arXiv:2303.00661',
#      '2023arXiv230300661S',
#      '10.48550/arXiv.2303.00661'],
#     'title': ['Spherical Harmonic Representation of Energetic Neutral Atom Flux Components Observed by IBEX']},
#    {'bibcode': '2023arXiv230300348H',
#     'identifier': ['2023arXiv230300348H',
#      '10.48550/arXiv.2303.00348',
#      'arXiv:2303.00348'],
#     'title': ['Compactified extra dimension and entanglement island as clues to quantum gravity']},
#    {'bibcode': '2023arXiv230300088G',
#     'identifier': ['2023arXiv230300088G',
#      '10.48550/arXiv.2303.00088',
#      'arXiv:2303.00088'],
#     'title': ['Quasi-normal modes of non-separable perturbation equations: the scalar non-Kerr case']},
#    {'bibcode': '2023arXiv230300718R',
#     'identifier': ['2023arXiv230300718R',
#      'arXiv:2303.00718',
#      '10.48550/arXiv.2303.00718'],
#     'title': ['Electric interface condition for sliding and viscous contacts']},
#    {'bibcode': '2023arXiv230300604L',
#     'identifier': ['2023arXiv230300604L',
#      '10.48550/arXiv.2303.00604',
#      'arXiv:2303.00604'],
#     'title': ['4D-EGB Black Holes in RPS Thermodynamics']},
#    {'bibcode': '2023arXiv230300022Y',
#     'identifier': ['arXiv:2303.00022',
#      '10.48550/arXiv.2303.00022',
#      '2023arXiv230300022Y'],
#     'title': ['daemonflux: DAta-drivEn MuOn-calibrated Neutrino Flux']},
#    {'bibcode': '2023arXiv230300218N',
#     'identifier': ['arXiv:2303.00218',
#      '10.48550/arXiv.2303.00218',
#      '2023arXiv230300218N'],
#     'title': ['Lifshitz motivated black holes in two-dimensional dilaton gravity']},
#    {'bibcode': '2023arXiv230300342K',
#     'identifier': ['arXiv:2303.00342',
#      '10.48550/arXiv.2303.00342',
#      '2023arXiv230300342K'],
#     'title': ['Reheating consistency condition on the classically conformal $U(1)_{B-L}$ Higgs inflation model']},
#    {'bibcode': '2023arXiv230300572E',
#     'identifier': ['2023arXiv230300572E',
#      'arXiv:2303.00572',
#      '10.48550/arXiv.2303.00572'],
#     'title': ['Nonminimally-coupled warm Higgs inflation: Metric vs. Palatini Formulations']},
#    {'bibcode': '2023arXiv230300317H',
#     'identifier': ['10.48550/arXiv.2303.00317',
#      '2023arXiv230300317H',
#      'arXiv:2303.00317'],
#     'title': ['Charged test-particle scattering and effective one-body metrics with spin']},
#    {'bibcode': '2023arXiv230300018M',
#     'identifier': ['2023arXiv230300018M',
#      '10.48550/arXiv.2303.00018',
#      'arXiv:2303.00018'],
#     'title': ['Entanglement Negativity Transitions in Chaotic Eigenstates']},
#    {'bibcode': '2023arXiv230300249K',
#     'identifier': ['2023arXiv230300249K',
#      'arXiv:2303.00249',
#      '10.48550/arXiv.2303.00249'],
#     'title': ['Possible relationship between initial conditions for inflation and past geodesic incompleteness of the inflationary spacetime']}]}}

# %%
"2305.02296"
re.search("^\d+\.\d+$", "2021ITPSy..36.2891S") is None
# .group()
# Out:
# True

# %%
for p in results.json()["response"]["docs"]:
    print(p["title"])
    break
# Out:
# ['A red giant orbiting a black hole']

# %%
arxiv_ids = ["a"]
ads_bibs = ["b"]

def read_ads_results(results, arxiv_ids=arxiv_ids, ads_bibs=ads_bibs):
    for paper in results:
        identifiers = paper["identifier"]
        
        found_arxiv_id = False
        for id_ in identifiers:
            if id_[:6] == "arXiv:":
                if id_[6:] not in arxiv_ids:
                    arxiv_ids.append(id_[6:])
                found_arxiv_id = True
                
        if not found_arxiv_id:
            if paper["bibcode"] not in ads_bibs:
                ads_bibs.append(paper["bibcode"])

    return arxiv_ids, ads_bibs
                
read_ads_results(results.json()["response"]["docs"])
arxiv_ids
# Out:
# ['a',
#  '2302.07880',
#  '2211.09097',
#  '2303.01636',
#  '2204.02695',
#  '2303.05574',
#  '2212.07540',
#  '2302.12234',
#  '2207.05765',
#  '2303.03775',
#  '2205.15325',
#  '2302.06629',
#  '2212.01405',
#  '2303.01532',
#  '2303.11321',
#  '2304.04004',
#  '2303.00768',
#  '2302.07342',
#  '2303.16923',
#  '2211.16725',
#  '2303.11036',
#  '2208.03468',
#  '2303.03232',
#  '2301.10259',
#  '2304.00329',
#  '2211.11790',
#  '1605.05160',
#  '2302.05479',
#  '2301.10614',
#  '2208.10528',
#  '2202.01242',
#  '2302.06500',
#  '2303.12686',
#  '2301.10252',
#  '2212.06195',
#  '2303.06909',
#  '2212.06182',
#  '2211.09890',
#  '2302.13903',
#  '2303.07721',
#  '2301.13453',
#  '2208.04292',
#  '2302.02005',
#  '2209.05495',
#  '2303.01637',
#  '2207.04542',
#  '2211.02059',
#  '2303.03989',
#  '2301.09865',
#  '2302.06644',
#  '2305.01014',
#  '2212.05070',
#  '2210.02472',
#  '2301.01065',
#  '2303.01349',
#  '2303.02263',
#  '2304.05777',
#  '2304.06291',
#  '2207.13860',
#  '2304.13843',
#  '2302.14347',
#  '2302.03105',
#  '2212.14539',
#  '2301.03068',
#  '2301.05166',
#  '2301.07398',
#  '2302.07057',
#  '2303.08205',
#  '1711.11449',
#  '2303.00291',
#  '2301.03626',
#  '2201.07512',
#  '2209.09256',
#  '2301.09652',
#  '2303.10189',
#  '2302.12848',
#  '2303.16204',
#  '2303.10013',
#  '2304.12028',
#  '2302.02682',
#  '2303.12845',
#  '2305.01007',
#  '2301.06779',
#  '2305.01335',
#  '2303.12530',
#  '2305.01493',
#  '2305.00999',
#  '2210.16921',
#  '2303.00770',
#  '2302.14203',
#  '2304.03015',
#  '2304.08514',
#  '2210.09856',
#  '2211.16388',
#  '2304.13283',
#  '2305.01627',
#  '2302.09763',
#  '2211.02651',
#  '2301.08271',
#  '2304.10485',
#  '2206.01758',
#  '2006.09159',
#  '1608.04169',
#  '2304.03863',
#  '2112.05543',
#  '2305.00998',
#  '2304.13044',
#  '2303.14016',
#  '2305.01075',
#  '2304.11581',
#  '2210.15372',
#  '2106.04980',
#  '2304.00308',
#  '2301.05401',
#  '2207.05189',
#  '2303.11948',
#  '2304.03975',
#  '2304.00515',
#  '2212.13946',
#  '2303.11209',
#  '2303.15695',
#  '2208.05491',
#  '2207.09540',
#  '2301.05075',
#  '1408.6953',
#  '2209.15066',
#  '2304.09549',
#  '2301.13038',
#  '2011.03130',
#  '2303.16121',
#  '2304.12357',
#  '2302.04011',
#  '2303.09959',
#  '2303.04717',
#  '2204.10835',
#  '2304.09642',
#  '2301.04529',
#  '2305.01000',
#  '2301.11939',
#  '2304.07864',
#  '2305.00993',
#  '2305.01436',
#  '2304.11296',
#  '2305.00988',
#  '2305.01582',
#  '2305.00108',
#  '2201.13274',
#  '1808.06559',
#  '1802.08152',
#  '2303.08344',
#  '2303.04556',
#  '1511.09380',
#  '1706.08769',
#  '1709.00202',
#  '2305.01250',
#  '2303.09259',
#  '2303.16049',
#  '2102.05353',
#  '2304.13057',
#  '2303.09984',
#  '2305.01533',
#  '2207.12383',
#  '2304.08129',
#  '2304.03248',
#  '2304.10886',
#  '2304.12661',
#  '2301.06398',
#  '2305.01042',
#  '2301.10019',
#  '2210.13482',
#  'quant-ph/0104088',
#  '2305.01431',
#  '2208.05218',
#  '2302.10466',
#  '2208.08808',
#  '2305.01307',
#  '2201.09915',
#  '2305.01562',
#  '2304.13779',
#  '2302.11579',
#  '2303.15351',
#  '2304.09295',
#  '2304.12705',
#  '2305.01594',
#  '1409.4518',
#  '1708.09049',
#  '2212.04494',
#  '2207.10124',
#  '2303.03431',
#  '2303.14394',
#  '2304.12938',
#  '2202.09640',
#  '2211.05900',
#  '1702.04616',
#  '2303.09501',
#  '2302.11158',
#  '2305.01312',
#  '2303.12011',
#  '2203.02518',
#  '2206.02129',
#  '2304.12037',
#  '2303.18245',
#  '2301.03702',
#  '2211.08092',
#  '2208.11704',
#  '2301.04670',
#  '2301.12359',
#  '1608.04264',
#  '2303.15589',
#  '2301.02258',
#  '2305.01045',
#  '2201.05164',
#  '2211.04727',
#  '2303.16771',
#  '2304.11307',
#  '2303.13875',
#  '2302.11650',
#  '2304.13271',
#  '2304.11187',
#  '2305.00991',
#  '2204.01035',
#  '1608.02570',
#  '2208.01716',
#  '2207.03514',
#  '2303.11557',
#  '2210.06708',
#  '2210.14768',
#  '2304.09508',
#  '2304.13508',
#  '2303.00183',
#  '2305.00025',
#  '2305.01389',
#  '2304.10565',
#  '2304.12394',
#  '2302.02643',
#  '2208.07889',
#  '2210.09722',
#  '1403.6181',
#  '1703.09566',
#  '2303.13719',
#  '2305.00992',
#  '2305.01112',
#  '2305.01380',
#  '2303.14972',
#  '2206.00685',
#  'cond-mat/0402201',
#  '2305.01549',
#  '2305.01589',
#  '2303.16930',
#  '2208.04819',
#  '2301.01941',
#  '2301.09837',
#  '2304.13763',
#  '2305.01212',
#  '1701.08221',
#  '1811.08583',
#  '2206.14845',
#  '2303.14567',
#  '2303.11534',
#  '2304.13484',
#  '2212.05243',
#  '2212.00949',
#  '2304.05264',
#  '2301.12597',
#  '2206.13698',
#  '2212.09772',
#  '2304.14829',
#  '2305.00475',
#  '1902.07446',
#  '2212.08209',
#  '1811.04219',
#  '1704.07030',
#  '2302.02487',
#  '1310.1559',
#  '1308.2100',
#  '2206.01450',
#  '2302.14148',
#  '2210.14235',
#  '1906.04157',
#  '2211.16794',
#  '2305.01256',
#  '2302.01943',
#  '2305.01197',
#  '2212.06276',
#  '2208.00827',
#  '2205.03445',
#  '2305.01224',
#  '2305.01266',
#  '2305.01587',
#  '2305.01175',
#  '2303.07412',
#  '1602.01790',
#  '2204.06384',
#  '1611.01453',
#  '2212.05959',
#  '1611.06881',
#  '1412.8487',
#  '2006.13369',
#  '2301.05367',
#  '2210.11477',
#  '2301.01417',
#  '2207.13472',
#  'cond-mat/0312375',
#  '2206.07752',
#  '1907.07791',
#  '1904.00261',
#  '2304.06718',
#  '2305.01584',
#  '2303.11387',
#  '2305.01142',
#  '2003.05307',
#  '2304.10641',
#  '2212.08080',
#  '2211.01250',
#  '2305.01123',
#  '2302.01615',
#  '2207.10190',
#  '2301.02406',
#  '2305.01415',
#  '2305.01002',
#  '2209.07701',
#  '2207.07648',
#  '2301.11978',
#  '1703.03579',
#  '1607.08092',
#  '2205.11954',
#  '2209.08883',
#  '1609.02358',
#  '1708.04067',
#  '2211.02565',
#  '1810.12481',
#  '2211.07598',
#  '2304.03530',
#  '2207.06476',
#  '2304.06851',
#  '1812.08097',
#  '1909.11770',
#  '2301.11506',
#  '2305.00206',
#  '2304.08206',
#  '1901.09069',
#  '2212.08699',
#  '1808.03034',
#  '2205.11342',
#  '2207.13104',
#  '2208.09582',
#  '1409.0027',
#  '1704.07020',
#  '1612.07191',
#  '2102.01375',
#  '1512.03451',
#  '1703.07062',
#  '1608.01523',
#  '1709.02004',
#  '1505.05853',
#  '1702.02578',
#  '2301.04103',
#  '1802.07317',
#  '2206.15084',
#  '2305.01487',
#  '2305.01149',
#  '2301.05870',
#  '2305.01150',
#  '2305.00831',
#  '2305.01496',
#  '1711.10500',
#  '2302.02717',
#  '2305.01446',
#  '1512.06191',
#  '2301.06947',
#  '2210.11454',
#  '2305.01607',
#  '2206.15075',
#  '2212.11817',
#  '2301.11854',
#  '2101.10370',
#  '2302.14149',
#  '2305.01383',
#  '2304.12261',
#  '2212.01199',
#  '2206.04532',
#  '1702.03810',
#  '1703.00550',
#  '1201.1952',
#  '2303.03721',
#  '2210.03733',
#  '1511.03348',
#  '2210.15705',
#  '1303.3394',
#  '1810.03123',
#  '1612.03004',
#  '2302.02372',
#  '2111.10953',
#  '2211.14899',
#  '2304.13313',
#  '2304.05441',
#  '1702.06366',
#  '1903.08402',
#  '1905.01881',
#  '1510.06919',
#  '1708.04614',
#  '1412.3027',
#  '2208.03013',
#  '2207.10187',
#  '1804.01594',
#  '1508.06681',
#  '2209.11955',
#  '1707.07043',
#  '1805.04527',
#  '2007.10715',
#  '1704.08270',
#  '2206.13045',
#  '1611.06123',
#  '1608.02972',
#  '1509.02823',
#  '1505.06721',
#  '1807.05285',
#  '2209.09257',
#  '2207.03670',
#  '2211.14635',
#  '2210.14171',
#  '2210.05686',
#  '2207.02239',
#  '2301.07971',
#  '1909.12056',
#  '1708.06568',
#  '1605.05475',
#  '2103.06520',
#  '1608.05626',
#  '2211.11529',
#  '1510.09153',
#  '1504.06641',
#  '1612.09031',
#  '2102.02406',
#  '1708.02023',
#  '2203.03596',
#  '2103.15435',
#  '1609.05620',
#  '1712.05607',
#  '1708.05771',
#  '1701.03288',
#  '1510.05197',
#  '2206.05296',
#  '2207.09361',
#  '2212.14064',
#  '2303.01376',
#  '2305.01116',
#  '2305.01364',
#  '2304.00973',
#  '2209.02768',
#  '2304.12517',
#  '2112.08354',
#  '2003.06139',
#  '2211.08977',
#  '1702.02420',
#  '2305.01127',
#  '2305.01945',
#  '2305.01537',
#  '2302.07857',
#  '2305.00387',
#  '2305.01602',
#  '2305.00392',
#  '2305.01462',
#  '2304.01898',
#  '2301.06560',
#  '2304.10160',
#  '2305.01385',
#  '2011.00555',
#  '2302.11176',
#  '1511.07398',
#  '1503.00380',
#  '1808.06633',
#  '1803.00647',
#  '1711.03268',
#  '2202.11406',
#  '1909.12686',
#  '2304.01158',
#  '1609.09644',
#  '1805.00662',
#  '1511.08003',
#  '2209.01726',
#  '1703.09582',
#  '1605.04057',
#  '2008.08855',
#  '2110.12232',
#  '1801.10317',
#  '1808.01385',
#  '2304.06814',
#  '2304.13095',
#  '2304.01185',
#  '2210.17548',
#  '2302.06863',
#  '2212.13536',
#  '2211.03845',
#  '2212.08527',
#  '2211.09922',
#  '2302.00436',
#  '2203.11159',
#  '1904.06098',
#  '1810.11632',
#  '1703.07880',
#  '2209.08523',
#  '1503.07893',
#  '1701.02763',
#  '1801.07281',
#  '1612.06895',
#  'cond-mat/0008226',
#  '1611.03963',
#  '1701.00042',
#  '1801.00599',
#  '2209.08787',
#  '1702.06753',
#  '1806.07784',
#  '2301.01841',
#  '1602.02010',
#  '1709.01961',
#  '1601.00702',
#  '1409.4980',
#  '1811.03408',
#  '1512.03264',
#  '1605.08480']

# %%
ads_arxiv_ids = []
for i in range(len(ads_titles)):
    ids = results.json()["response"]["docs"][i]['identifier']
    for id_ in ids:
        try:
            result = re.search("arXiv:.*", id_).group()
        except:
            continue
    ads_arxiv_ids.append(result[6:])
    
print(len(ads_arxiv_ids))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 ads_arxiv_ids = []
# ----> 2 for i in range(len(ads_titles)):
#       3     ids = results.json()["response"]["docs"][i]['identifier']
#       4     for id_ in ids:
#
# NameError: name 'ads_titles' is not defined

# %%
n = 0
for id_ in email_arxiv_ids:
    if id_ not in ads_arxiv_ids:
        print(id_)
        n += 1
print(n, n/len(email_arxiv_ids))
# Out:
# 1609.06324
# 2301.06432
# 2304.07364
# 2010.15986
# 2103.00603
# 2202.13186
# 2205.07892
# 2206.10169
# 2207.10520
# 2207.11308
# 2209.11078
# 2210.00031
# 2210.08010
# 2211.13576
# 2211.16857
# 2212.04429
# 2212.13454
# 2301.01312
# 2102.12495
# 2301.02406
# 2301.05335
# 2301.07975
# 2301.09731
# 2301.10740
# 2302.10542
# 2302.12527
# 2303.00060
# 2303.16231
# 2304.02028
# 2304.02452
# 2304.05924
# 2304.07962
# 2304.08010
# 33 0.375

# %%
n = 0
for id_, title in zip(ads_arxiv_ids, ads_titles):
    if id_ not in email_arxiv_ids:
        print(id_, title)
        n += 1
print(n)
# Out:
# 1810.02965 Can Formamide Be Formed on Interstellar Ice? An Atomistic Perspective
# 1911.08991 Astrochemistry as a Tool To Follow Protostellar Evolution: The Class I Stage
# 1908.02960 Volatile Species in Comet 67P/Churyumov-Gerasimenko: Investigating the Link from the ISM to the Terrestrial Planets
# 1708.05559 Atom Tunneling in the Water Formation Reaction H2 + OH → H2O + H on an Ice Surface
# 2106.03558 Multiscale Photonic Emissivity Engineering for Relativistic Lightsail Thermal Regulation
# 2210.11890 Gauge theories on quantum spaces
# 2003.03967 CHO-Bearing Molecules in Comet 67P/Churyumov-Gerasimenko
# 2304.07370 The apparent absence of forward scattering in the HD 53143 debris disk
# 2304.07400 The Breakthrough Listen Search for Intelligent Life: Nearby Stars' Close Encounters with the Brightest Earth Transmissions
# 2304.07595 The Gravito-Maxwell Equations of General Relativity in the local reference frame of a GR-noninertial observer
# 2304.09098 On the seed population of solar energetic particles in the inner heliosphere
# 2304.08552 Catching Tidal Dwarf Galaxies at a Later Evolutionary Stage with ALFALFA
# 2304.08898 Galaxy pairs in The Three Hundred simulations II: studying bound ones and identifying them via machine learning
# 2304.08771 MHD study of extreme space weather conditions for exoplanets with Earth-like magnetospheres: On habitability conditions and radio-emission
# 2304.08668 Emerging planetary nebulae within 3D spiral patterns
# 2304.08514 An ultrafast outflow in the black hole candidate MAXI J1810-222?
# 2211.04239 Gravitational lensing by using the 0th order of affine perturbation series of the deflection angle of a ray near a photon sphere
# 2304.05191 Multicolor and multi-spot observations of Starlink's Visorsat
# 2301.12319 Hawking radiation inside a charged black hole
# 2301.11561 Control scheme for polarization circulation speed meter using a dual-retardation waveplate
# 2304.08690 Surface pressure impact on nitrogen-dominated USP super-Earth atmospheres
# 2301.02267 Identifying modified theories of gravity using binary black-hole ringdowns
# 2204.11867 Mass renormalization in lattice simulations of false vacuum decay
# 2212.05967 Second-generation time-delay interferometry
# 2212.08112 Superradiance and quasinormal modes of the gravitational perturbation around rotating hairy black hole
# 2212.05351 Unified model for the LISA measurements and instrument simulations
# 2205.15753 Binary dynamics from worldline QFT for scalar QED
# 2304.08517 JWST CEERS probes the role of stellar mass and morphology in obscuring galaxies
# 2304.08578 Combined Spectroscopic and Photometric Analysis of Flares in the Dwarf M Star EV Lacertae
# 2304.08676 Trajectories of astroparticles in pseudo-Finsler spacetime with the most general modified dispersion
# 2304.09038 Secular orbital dynamics of the innermost exoplanet of the $\upsilon$-Andromedæ system
# 2304.08839 The progenitors of Type Ia supernovae with asymptotic giant branch donors
# 2304.08618 The cosmic waltz of Coma Berenices and Latyshev 2 (Group X). Membership, phase-space structure, mass, and energy distributions
# 2304.08521 An Updated Dust-to-Star Geometry: Dust Attenuation Does Not Depend on Inclination in $1.3\leq z\leq 2.6$ Star-Forming Galaxies from MOSDEF
# 2203.09529 Asymptotic Measurement Schemes for Every Observable of a Quantum Field Theory
# 2206.12256 New anisotropic star solutions in mimetic gravity
# 2303.16630 Spontaneous scalarization in proto-neutron stars
# 2212.14526 D-Egg: a dual PMT optical module for IceCube
# 2211.00024 A robust estimator of mutual information for deep learning interpretability
# 2303.07978 Measurement of the Compton scattering in germanium with a p-type point-contact germanium detector for dark matter detection
# 2302.04414 Cosmology with the galaxy bispectrum multipoles: Optimal estimation and application to BOSS data
# 2209.11262 The inferred abundance of interstellar objects of technological origin
# 2304.08533 Astrophysical neutrino point sources as a probe of new physics
# 2304.08816 X-ray flashes from the low-mass X-ray binary IGR J17407-2808
# 2304.08646 Quantization of the anisotropic conformal Horava theory
# 2304.09166 A Cross-Internal Linear Combination Approach to Probe the Secondary CMB Anisotropies: Kinematic Sunyaev-Zel{'}dovich Effect and CMB Lensing
# 2304.09150 Constraints on Europa's water group torus from HST/COS observations
# 2304.08659 Global dynamics in Einstein-Gauss-Bonnet scalar field cosmology with matter
# 2304.09122 Optical darkness in short-duration $\gamma$-ray bursts
# 2304.09449 Global Existence and Completeness of Classical Solutions in Einstein-Klein-Gordon System in Higher Dimensions
# 2304.08725 Ultra-high-resolution Observations of Persistent Null-point Reconnection in the Solar Corona
# 2201.12824 On the angular momentum of compact binary coalescence
# 2212.07947 Wald-Zoupas prescription with soft anomalies
# 2304.09142 Cosmology with Galaxy Cluster Properties using Machine Learning
# 2304.08516 JADES: Insights on the low-mass end of the mass--metallicity--star-formation rate relation at $3 &lt; z &lt; 10$ from deep JWST/NIRSpec spectroscopy
# 2304.09482 Standard quantum field theory from entangled relativity
# 2210.01372 The criteria of the anisotropic quark star models in Rastall gravity
# 2304.08510 On the classification of Generalized Quasitopological Gravities
# 2304.08523 Equivalences between 2D dilaton gravities, their asymptotic symmetries, and their holographic duals
# 2212.02829 Searches for mass-asymmetric compact binary coalescence events using neural networks in the LIGO/Virgo third observation period
# 2304.09060 Mass measurements and 3D orbital geometry of PSR J1933$-$6211
# 2304.09052 Gravitational scattering upto third post-Newtonian approximation for conservative dynamics: Scalar-Tensor theories
# 2304.08666 Identification of Extended Emission Gamma-Ray-Bursts Candidates using Machine Learning
# 2206.15087 Sub-barrier fusion hindrance and absence of neutron transfer channels
# 2207.14025 Local space time constant mean curvature and constant expansion foliations
# 2304.09671 Modified General Relativity and dark matter
# 2304.08824 A Dark Matter Probe in Accreting Pulsar-Black Hole Binaries
# 2304.09168 A practical guide to a moment approach for neutrino transport in numerical relativity
# 2304.09136 The effect of the LMC on the Milky Way system
# 2303.07238 Relativistic stellar modeling with perfect fluid core and anisotropic envelope fluid
# 2304.09129 First constraints of dense molecular gas at z~7.5 from the quasar Pōniuā'ena
# 2304.08877 Complexity factor Parametrization for Traversable Wormholes
# 2304.09163 Cosmo-dynamics of dark energy models resulting from a parametrization of $H$ in $f(Q,T)$ gravity
# 2211.07840 Casimir tests of scalar-tensor theories
# 2210.08254 Evolution of collisional neutrino flavor instabilities in spherically symmetric supernova models
# 2212.07186 Subdominant modes of the scalar superradiant instability and gravitational wave beats
# 2304.08527 Higher derivative corrections to black hole thermodynamics at NNLO
# 2304.09432 Replica wormhole as a vacuum-to-vacuum transition
# 2304.08888 LIGO-VIRGO constraints on dark matter and leptogenesis triggered by a first order phase transition at high scale
# 2304.08969 Dynamic behaviours of black hole phase transitions near quadruple points
# 2304.05408 Einstein-Rosen bridge from the minimal length
# 2211.11868 Torsional dark energy in quadratic gauge gravity
# 2303.02487 WGC and WCCC of black holes with quintessence and cloud strings in RPS space
# 2304.09200 Comparison of post-Minkowskian and self-force expansions: Scattering in a scalar charge toy model
# 2212.03052 Gravitational corrections to electroweak vacuum decay: metric vs. Palatini
# 2304.09140 A Sun-like star orbiting a boson star
# 2304.08520 Message in a bottle: energy extraction from bouncing geometries
# 2304.08731 The impact of halo concentration on the Sunyaev Zel'dovich effect signal from massive galaxy clusters
# 2209.12404 Primordial black holes and third order scalar induced gravitational waves
# 2210.04784 Extraction energy from charged Vaidya black hole via the Penrose process
# 2301.08253 NSC++: Non-standard cosmologies in C++
# 2211.00578 Investigating the Hubble tension: Effect of cepheid calibration
# 2210.06533 Super-Fermi acceleration in multiscale MHD reconnection
# 2212.03909 Numerical-relativity-informed effective-one-body model for black-hole-neutron-star mergers with higher modes and spin precession
# 2304.08518 Mapping the Skies of Ultracool Worlds: Detecting Storms and Spots with Extremely Large Telescopes
# 2304.08810 Physical cool-core condensation radius in massive galaxy clusters
# 2304.09035 Evolution of matter and galaxy clustering in cosmological hydrodynamical simulations
# 2304.08561 Zenith-Angular Characteristics of Particles in EASs with $E_0 \simeq 10^{18}$ eV According to the Yakutsk Array Data
# 2304.08546 Bayesian averaging for ground state masses of atomic nuclei in a Machine Learning approach
# 2304.08835 Spin-Gravity Coupling in a Rotating Universe
# 2212.10853 A new formulation of general-relativistic hydrodynamic equations using primitive variables
# 2210.15685 Exotic marginally outer trapped surfaces in rotating spacetimes of any dimension
# 2212.00037 Integrable models based on non-semi-simple groups and plane wave target spacetimes
# 2304.09662 TEOBResumS: Analytic systematics in next-generation of effective-one-body gravitational waveform models for future observations
# 2304.08511 JWST/NIRSpec Measurements of Extremely Low Metallicities in High Equivalent Width Lyman-$\alpha$ Emitters
# 2304.08513 Current and Future constraints on Very-Light Axion-Like Particles from X-ray observations of cluster-hosted Active Galaxies
# 2304.08995 The Simons Observatory: Beam characterization for the Small Aperture Telescopes
# 2303.14388 Relative efficiency of three mechanisms of vector field growth in a random media
# 2304.02522 Quantitative constraints on modified gravity paradigms
# 2211.15580 Effective-one-body Hamiltonian in scalar-tensor gravity at third post-Newtonian order
# 2304.09363 Characteristic modes of thick brane model: resonances and quasinormal modes
# 2203.04140 Fermionic and bosonic greybody factors as well as quasinormal modes for charged Taub NUT black holes
# 2301.06600 Are inertial vacua equivalent in Lorentz-violating theories? Does it matter?
# 2211.00085 Classical vs quantum eikonal scattering and its causal structure
# 2205.05903 Entropies of the various components of the universe
# 2212.06554 A Stationary Black Hole Must be Axisymmetric in Effective Field Theory
# 2201.09232 Anomaly-free scale symmetry and gravity
# 2207.14683 On the emergence of a classical isotropic universe from a quantum f(R) Bianchi cosmology in the Jordan frame
# 2303.05712 Detection of a new molecular cloud in the LHAASO J2108+5157 region supporting a hadronic PeVatron scenario
# 2212.09827 Current induction and macroscopic forces for superconducting strings
# 2304.09080 Holographic inflation in non-static plane symmetric space-time
# 2304.09749 Some diagnostic analysis of dark energy models with $q(z)$ parametrizations
# 2304.08726 Two-injection scenario for the hard X-ray excess observed in Mrk 421
# 2211.11022 Dusty plasma in active galactic nuclei
# 2203.02409 From spin foams to area metric dynamics to gravitons
# 2205.02256 Aspects of holography in conical AdS<SUB>3</SUB>
# 2212.03403 Generation of primordial black holes from an inflation model with modified dispersion relation
# 2304.09777 Novel charged black hole solutions of Born-Infeld type: General properties, Smarr formula and Quasinormal frequencies
# 2304.08613 The Panchromatic Hubble Andromeda Treasury XX: The Disk of M31 is Thick
# 2304.08828 Tidal disruption events and quasi periodic eruptions
# 2304.08776 Hot and highly magnetized neutron star matter properties with Skyrme interactions
# 2304.08874 Anisotropic power-law inflation for a generalized model of two scalar and two vector fields
# 2201.10288 Linear Stability of Semiclassical Theories of Gravity
# 2301.03744 Inflation in Weyl scaling invariant gravity with R<SUP>3</SUP> extensions
# 2212.01723 On heat properties of charged AdS black holes in Gauss-Bonnet gravity coupled with nonlinear electrodynamics
# 2301.08773 Laboratory study of the failed torus mechanism in arched, line-tied, magnetic flux ropes
# 2304.09291 Integrability of Dirac equations in static spherical space-times
# 2304.08656 Constraints on extended Jordan-Brans-Dicke gravity
# 2304.09014 Micro-canonical and canonical description for generalised entropy
# 2304.09051 Possible origin of AT2021any: a failed GRB from a structured jet
# 2304.08827 The evolutionary route to form planetary nebulae with central neutron star - white dwarf binaries
# 2206.06397 A gravitationally induced decoherence model using Ashtekar variables
# 2209.05792 Entanglement entropy of local gravitational quenches
# 2207.00557 Experimental simulation of loop quantum gravity on a photonic chip
# 2304.09330 Phase Space Renormalization and Finite BMS Charges in Six Dimensions
# 2207.02881 Markov chain Monte Carlo methods for graph refinement in spinfoam cosmology
# 2209.00960 Thermodynamics of Schwarzschild black hole surrounded by quintessence in gravity's rainbow
# 2211.07878 Characterizing a supernova's standing accretion shock instability with neutrinos and gravitational waves
# 2211.03926 Exact formulations of relativistic electrodynamics and magnetohydrodynamics with helically coupled scalar field
# 2304.08574 Equivalence principle, de-Sitter space, and cosmological twistors
# 2304.08624 Effective description of generalized disformal theories
# 2304.08812 On two body gravitational scattering within perturbative gravit
# 2304.08723 Root-$T \overline{T}$ Deformed Boundary Conditions in Holography
# 2304.09506 Nonlinear realisation approach to topologically massive supergravity
# 2304.08986 Star formation in the dwarf Seyfert galaxy NGC 4395: Evidence for both AGN and SNe feedback?
# 2301.13678 Boson mixing and flavor vacuum in the expanding Universe: A possible candidate for the dark energy
# 2304.08831 Energy extraction from rotating regular black hole via magnetic reconnection
# 2304.08751 Chaos and fast scrambling delays of dyonic Kerr-Sen-AdS$_4$ black hole and its ultra-spinning version
# 2304.09760 Thermodynamic Instabilities of Conformal Gravity Holography in Four Dimensions
# 2211.02197 Axion cosmology with post-Newtonian corrections
# 2304.09025 Tests of modified gravitational wave propagations with gravitational waves
# 2304.09332 Nonexistence of Solutions to the Coupled Generalized Jang Equation/Zero Divergence System
# 2304.09436 Holographic realization of constant roll inflation and dark energy: An unified scenario
# 2304.08729 Quantum atmosphere effective radii for different spin fields from quantum gravity inspired black holes
# 2303.00190 Gravitational lensing by a charged spherically symmetric black hole immersed in thin dark matter
# 2209.12415 Detecting sublunar-mass primordial black holes with the Earth-Moon binary system
# 2206.13209 Big bang nucleosynthesis constraints on varying electron mass solution to the Hubble tension
# 2302.04289 Framework for phase transitions between the Maxwell and Gibbs constructions
# 2212.00560 Axion minivoids and implications for direct detection
# 2304.08563 The Way of Water: ALMA resolves H2O emission lines in a strongly lensed dusty star-forming galaxy at z $\sim$ 3.1
# 2303.04153 Gravastar in the framework of symmetric teleparallel gravity
# 2209.08502 Null test for cosmic curvature using Gaussian process
# 2209.02763 Dispersive censor of acoustic spacetimes with a shock-wave singularity
# 2204.06807 Constraining deviations from spherical symmetry using γ -metric
# 2210.09357 Gravitational-wave imprints of compact and galactic-scale environments in extreme-mass-ratio binaries
# 2301.01070 Nonlocal-in-time effective one body Hamiltonian in scalar-tensor gravity at third post-Newtonian order
# 2210.15601 Discrete bulk reconstruction
# 2304.08519 Persistent and occasional: searching for the variable population of the ZTF/4MOST sky using ZTF data release 11
# 2304.08584 Numerical simulations of divergence-type theories for conformal dissipative fluids
# 2304.09169 The role of mass and environment in the build up of the quenched galaxy population since cosmic noon
# 2211.07376 Qualitative stability analysis of cosmological parameters in f(T, B) gravity
# 2208.06899 Study of stationary rigidly rotating anisotropic cylindrical fluids with new exact interior solutions of GR. III. Azimuthal pressure
# 2212.12601 Polar modes and isospectrality of Ellis-Bronnikov wormholes
# 2304.09847 Ionization temperature in Schwarzschild-de Sitter spacetime
# 2302.08900 Stability and physical properties of spherical excited scalar boson stars
# 2304.08526 The Physics of Indirect Estimators of Lyman Continuum Escape and their Application to High-Redshift JWST Galaxies
# 2304.08524 The dynamical mass of the white dwarf in XY Ari questions intermediate polar X-ray spectral models
# 2304.09002 Cosmo-tomography toward PKS1830-211: Variability of the quasar and of its foreground molecular absorption monitored with ALMA
# 2304.09041 Joint measurement of the galaxy cluster pressure profile with Planck and SPT-SZ
# 2304.08585 Radiometry for Nighttime Sub-Cloud Imaging of Venus' Surface in the Near-InfraRed Spectrum
# 190

# %%
start_day = 3
start_month = 5
start_year = 2023

end_day = 5
end_month = 5
end_year = 2023

if start_day < 10:
    start_day = f"0{start_day}"
if start_month < 10:
    start_month = f"0{start_month}"
if end_day < 10:
    end_day = f"0{end_day}"
if end_month < 10:
    end_month = f"0{end_month}"

encoded_query = urlencode({"q": f"metadata_mtime:[{start_year}-{start_month}-{start_day}T00\:00\:00.000Z TO {end_year}-{end_month}-{end_day}T00\:00\:00.000Z]", "fl": "bibcode, identifier", "rows": 9999})

results = requests.get("https://api.adsabs.harvard.edu/v1/search/query?{}".format(encoded_query), headers={'Authorization': 'Bearer ' + ADS_DEV_KEY})
results.json()
# [2023-05-03T22\:00\:00.000Z TO 2023-05-04T12\:00\:00.000Z]
# Out:
# {'responseHeader': {'status': 0,
#   'QTime': 29,
#   'params': {'q': 'metadata_mtime:[2023-05-03T00\\:00\\:00.000Z TO 2023-05-05T00\\:00\\:00.000Z]',
#    'fl': 'bibcode,identifier',
#    'start': '0',
#    'internal_logging_params': 'X-Amzn-Trace-Id=Root=1-64553e36-67d51fbb4c0f125b1fa539ec',
#    'rows': '2000',
#    'wt': 'json'}},
#  'response': {'numFound': 66845,
#   'start': 0,
#   'docs': [{'bibcode': '2023MNRAS.521.4323E',
#     'identifier': ['10.1093/mnras/stad799',
#      'arXiv:2302.07880',
#      '2023arXiv230207880E',
#      '2023MNRAS.521.4323E',
#      '10.48550/arXiv.2302.07880']},
#    {'bibcode': '2001JPet...42.2033F',
#     'identifier': ['10.1093/petrology/42.11.2033', '2001JPet...42.2033F']},
#    {'bibcode': '2023ApJ...947L..24M',
#     'identifier': ['10.3847/2041-8213/acb99e',
#      '10.48550/arXiv.2211.09097',
#      'arXiv:2211.09097',
#      '2022arXiv221109097M',
#      '2023ApJ...947L..24M']},
#    {'bibcode': '2005PreR..136..177Z',
#     'identifier': ['10.1016/j.precamres.2004.10.002', '2005PreR..136..177Z']},
#    {'bibcode': '1988CMAME..71..197B',
#     'identifier': ['10.1016/0045-7825(88)90086-2', '1988CMAME..71..197B']},
#    {'bibcode': '2023MNRAS.521.3991B',
#     'identifier': ['10.48550/arXiv.2303.01636',
#      '2023MNRAS.521.3991B',
#      '10.1093/mnras/stad631',
#      'arXiv:2303.01636',
#      '2023arXiv230301636B',
#      '2023MNRAS.tmp..617B']},
#    {'bibcode': '2023MNRAS.518.1002R',
#     'identifier': ['10.1093/mnras/stac3074',
#      '2022MNRAS.tmp.2863R',
#      'arXiv:2204.02695',
#      '2022arXiv220402695R',
#      '2023MNRAS.518.1002R',
#      '10.48550/arXiv.2204.02695']},
#    {'bibcode': '2004QuRes..62..243M',
#     'identifier': ['10.1016/j.yqres.2004.07.001', '2004QuRes..62..243M']},
#    {'bibcode': '2023ApJ...947...80B',
#     'identifier': ['10.3847/1538-4357/acc469',
#      '2023ApJ...947...80B',
#      'arXiv:2303.05574',
#      '10.48550/arXiv.2303.05574',
#      '2023arXiv230305574B']},
#    {'bibcode': '2023APh...15002850A',
#     'identifier': ['arXiv:2303.15007',
#      '2023APh...15002850A',
#      '2023arXiv230315007T',
#      '10.1016/j.astropartphys.2023.102850',
#      '10.48550/arXiv.2303.15007',
#      '2023arXiv230315007C']},
#    {'bibcode': '1955PPSA...68.1113K',
#     'identifier': ['1955PPSA...68.1113K', '10.1088/0370-1298/68/12/303']},
#    {'bibcode': '2022arXiv221207540A',
#     'identifier': ['arXiv:2212.07540',
#      '2022arXiv221207540A',
#      '10.48550/arXiv.2212.07540']},
#    {'bibcode': '2023MNRAS.tmp.1180L',
#     'identifier': ['arXiv:2302.12234',
#      '10.48550/arXiv.2302.12234',
#      '10.1093/mnras/stad1263',
#      '2023MNRAS.tmp.1180L',
#      '2023arXiv230212234L']},
#    {'bibcode': '2023CQGra..40i4001K',
#     'identifier': ['10.48550/arXiv.2207.05765',
#      'arXiv:2207.05765',
#      '2022arXiv220705765A',
#      '2023CQGra..40i4001K',
#      '10.1088/1361-6382/acbefc']},
#    {'bibcode': '2023A&A...673A...4B',
#     'identifier': ['2023A&A...673A...4B',
#      '10.48550/arXiv.2303.03775',
#      '2023arXiv230303775B',
#      'arXiv:2303.03775',
#      '10.1051/0004-6361/202245741']},
#    {'bibcode': '2023MNRAS.tmp.1137F',
#     'identifier': ['2022arXiv220515325F',
#      '10.48550/arXiv.2205.15325',
#      'arXiv:2205.15325',
#      '2023MNRAS.tmp.1137F',
#      '10.1093/mnras/stad1205']},
#    {'bibcode': '2023A&A...673A..13M',
#     'identifier': ['2023A&A...673A..13M',
#      '10.1051/0004-6361/202245046',
#      'arXiv:2302.06629',
#      '2023arXiv230206629M',
#      '10.48550/arXiv.2302.06629']},
#    {'bibcode': '2023ApJ...947...66F',
#     'identifier': ['2023ApJ...947...66F',
#      '10.3847/1538-4357/acb5f4',
#      '2022arXiv221201405F',
#      '10.48550/arXiv.2212.01405',
#      'arXiv:2212.01405']},
#    {'bibcode': '2023PASJ..tmp...42M',
#     'identifier': ['2023arXiv230301532M',
#      '10.1093/pasj/psad024',
#      'arXiv:2303.01532',
#      '2023PASJ..tmp...42M',
#      '10.48550/arXiv.2303.01532']},
#    {'bibcode': '2023MNRAS.tmp.1170B',
#     'identifier': ['10.48550/arXiv.2303.11321',
#      'arXiv:2303.11321',
#      '10.1093/mnras/stad1259',
#      '2023arXiv230311321B',
#      '2023MNRAS.tmp.1170B']},
#    {'bibcode': '2023MNRAS.tmp.1041D',
#     'identifier': ['10.48550/arXiv.2304.04004',
#      '2023MNRAS.tmp.1041D',
#      '10.1093/mnras/stad1076',
#      '2023arXiv230404004D',
#      'arXiv:2304.04004']},
#    {'bibcode': '2023arXiv230300768L',
#     'identifier': ['2023arXiv230300768L',
#      '10.48550/arXiv.2303.00768',
#      'arXiv:2303.00768']},
#    {'bibcode': '2023ApJ...947...62K',
#     'identifier': ['2023ApJ...947...62K',
#      'arXiv:2302.07342',
#      '10.48550/arXiv.2302.07342',
#      '2023arXiv230207342K',
#      '10.3847/1538-4357/acbcd3']},
#    {'bibcode': '1996Oecol.108..389J',
#     'identifier': ['10.1007/BF00333714', '1996Oecol.108..389J']},
#    {'bibcode': '2023ApJ...947L..30C',
#     'identifier': ['10.48550/arXiv.2303.16923',
#      '2023arXiv230316923C',
#      '2023ApJ...947L..30C',
#      '10.3847/2041-8213/acc86d',
#      'arXiv:2303.16923']},
#    {'bibcode': '2022arXiv221116725G',
#     'identifier': ['2022arXiv221116725G',
#      '10.48550/arXiv.2211.16725',
#      'arXiv:2211.16725']},
#    {'bibcode': '2023ApJ...948....3U',
#     'identifier': ['arXiv:2303.11036',
#      '10.3847/1538-4357/acc530',
#      '2023arXiv230311036U',
#      '10.48550/arXiv.2303.11036',
#      '2023ApJ...948....3U']},
#    {'bibcode': '2023ApJ...947L..25G',
#     'identifier': ['10.3847/2041-8213/acba8b',
#      'arXiv:2208.03468',
#      '10.48550/arXiv.2208.03468',
#      '2022arXiv220803468G',
#      '2023ApJ...947L..25G']},
#    {'bibcode': '2023MNRAS.tmp.1160B',
#     'identifier': ['arXiv:2303.03232',
#      '10.1093/mnras/stad1247',
#      '2023arXiv230303232B',
#      '2023MNRAS.tmp.1160B',
#      '10.48550/arXiv.2303.03232']},
#    {'bibcode': '2023MNRAS.tmp.1136V',
#     'identifier': ['2023arXiv230110259V',
#      '10.1093/mnras/stad1201',
#      '10.48550/arXiv.2301.10259',
#      '2023MNRAS.tmp.1136V',
#      'arXiv:2301.10259']},
#    {'bibcode': '2023ApJ...947L..18S',
#     'identifier': ['2023arXiv230400329S',
#      'arXiv:2304.00329',
#      '10.48550/arXiv.2304.00329',
#      '10.3847/2041-8213/acc940',
#      '2023ApJ...947L..18S']},
#    {'bibcode': '2023A&A...673A..23S',
#     'identifier': ['2022arXiv221111790S',
#      '2023A&A...673A..23S',
#      'arXiv:2211.11790',
#      '10.48550/arXiv.2211.11790',
#      '10.1051/0004-6361/202245509']},
#    {'bibcode': '2023PhRvD.107h3504A',
#     'identifier': ['arXiv:2207.05766',
#      '10.48550/arXiv.2207.05766',
#      '2022arXiv220705766D',
#      '10.1103/PhysRevD.107.083504',
#      '2023PhRvD.107h3504A']},
#    {'bibcode': '1988JVSTA...6.2390B',
#     'identifier': ['1988JVSTA...6.2390B',
#      '1988JVST....6.2390B',
#      '10.1116/1.575561']},
#    {'bibcode': '2002IJCli..22.1441K',
#     'identifier': ['2002IJCli..22.1441K', '10.1002/joc.773']},
#    {'bibcode': '2016MNRAS.461.3683I',
#     'identifier': ['arXiv:1605.05160',
#      '10.1093/mnras/stw1205',
#      '2016MNRAS.461.3683I',
#      '2016arXiv160505160I',
#      '10.48550/arXiv.1605.05160']},
#    {'bibcode': '2023MNRAS.tmp.1191L',
#     'identifier': ['10.48550/arXiv.2302.05479',
#      '2023arXiv230205479L',
#      '2023MNRAS.tmp.1191L',
#      '10.1093/mnras/stad1272',
#      'arXiv:2302.05479']},
#    {'bibcode': '2023A&A...673A..14C',
#     'identifier': ['10.48550/arXiv.2301.10614',
#      'arXiv:2301.10614',
#      '2023arXiv230110614C',
#      '10.1051/0004-6361/202245131',
#      '2023A&A...673A..14C']},
#    {'bibcode': '2022arXiv220810528H',
#     'identifier': ['10.48550/arXiv.2208.10528',
#      'arXiv:2208.10528',
#      '2022arXiv220810528H']},
#    {'bibcode': '2023ApJ...947...16A',
#     'identifier': ['10.48550/arXiv.2202.01242',
#      'arXiv:2202.01242',
#      '2023ApJ...947...16A',
#      '10.3847/1538-4357/acb13f',
#      '2022arXiv220201242C']},
#    {'bibcode': '2023ApJ...947...68I',
#     'identifier': ['arXiv:2302.06500',
#      '2023arXiv230206500I',
#      '2023ApJ...947...68I',
#      '10.3847/1538-4357/acb4ea',
#      '10.48550/arXiv.2302.06500']},
#    {'bibcode': '2023arXiv230312686C',
#     'identifier': ['2023arXiv230312686C',
#      '10.48550/arXiv.2303.12686',
#      'arXiv:2303.12686']},
#    {'bibcode': '2023ApJ...948....5F',
#     'identifier': ['2023arXiv230110252F',
#      '10.48550/arXiv.2301.10252',
#      '10.3847/1538-4357/acbfb7',
#      'arXiv:2301.10252',
#      '2023ApJ...948....5F']},
#    {'bibcode': '2023MNRAS.tmp.1143D',
#     'identifier': ['10.1093/mnras/stad1171',
#      'arXiv:2212.06195',
#      '2023MNRAS.tmp.1143D',
#      '10.48550/arXiv.2212.06195',
#      '2022arXiv221206195D']},
#    {'bibcode': '2023arXiv230306909B',
#     'identifier': ['10.48550/arXiv.2303.06909',
#      '2023arXiv230306909B',
#      'arXiv:2303.06909']},
#    {'bibcode': '2023ApJ...947...74L',
#     'identifier': ['10.3847/1538-4357/acc02a',
#      '2023ApJ...947...74L',
#      '10.48550/arXiv.2212.06182',
#      'arXiv:2212.06182',
#      '2022arXiv221206182L']},
#    {'bibcode': '2003MWRv..131.2394B',
#     'identifier': ['10.1175/1520-0493(2003)131<2394:RRFTSO>2.0.CO2',
#      '2003MWRv..131.2394B']},
#    {'bibcode': '2003JVSTA..21S.117P',
#     'identifier': ['2003JVSTA..21S.117P',
#      '2003JVST...21S.117P',
#      '10.1116/1.1601610']},
#    {'bibcode': '1980ClCh....2..207S',
#     'identifier': ['10.1007/BF00137988', '1980ClCh....2..207S']},
#    {'bibcode': '2023PASP..135d8002R',
#     'identifier': ['2022arXiv221109890R',
#      '2023PASP..135d8002R',
#      'arXiv:2211.09890',
#      '10.1088/1538-3873/acbcf4',
#      '10.48550/arXiv.2211.09890']},
#    {'bibcode': '2023ApJS..266....7T',
#     'identifier': ['10.48550/arXiv.2302.13903',
#      '2023arXiv230213903T',
#      'arXiv:2302.13903',
#      '10.3847/1538-4365/acc2c0',
#      '2023ApJS..266....7T']},
#    {'bibcode': '2023A&A...673A..27N',
#     'identifier': ['2023A&A...673A..27N',
#      'arXiv:2303.07721',
#      '10.48550/arXiv.2303.07721',
#      '2023arXiv230307721N',
#      '10.1051/0004-6361/202346084']},
#    {'bibcode': '2023ApJ...948....9I',
#     'identifier': ['10.3847/1538-4357/acb7e8',
#      '10.48550/arXiv.2301.13453',
#      '2023ApJ...948....9I',
#      'arXiv:2301.13453',
#      '2023arXiv230113453I']},
#    {'bibcode': '2023ApJ...947L..27D',
#     'identifier': ['arXiv:2208.04292',
#      '10.48550/arXiv.2208.04292',
#      '10.3847/2041-8213/ac9ebb',
#      '2022arXiv220804292D',
#      '2023ApJ...947L..27D']},
#    {'bibcode': '2003IJSEd..25.1049O',
#     'identifier': ['2003IJSEd..25.1049O', '10.1080/0950069032000032199']},
#    {'bibcode': '2023MLS&T...4b5013C',
#     'identifier': ['10.1088/2632-2153/acca5f',
#      '2023MLS&T...4b5013C',
#      '2023arXiv230202005C',
#      'arXiv:2302.02005',
#      '10.48550/arXiv.2302.02005']},
#    {'bibcode': '2023A&A...671A.160G',
#     'identifier': ['10.1051/0004-6361/202244935',
#      '2023A&A...671A.160G',
#      '2022arXiv220905495G',
#      'arXiv:2209.05495',
#      '10.48550/arXiv.2209.05495']},
#    {'bibcode': '2023MNRAS.tmp.1189D',
#     'identifier': ['10.48550/arXiv.2303.01637',
#      '2023MNRAS.tmp.1189D',
#      '2023arXiv230301637D',
#      '10.1093/mnras/stad1254',
#      'arXiv:2303.01637']},
#    {'bibcode': '2023MNRAS.tmp.1184H',
#     'identifier': ['2022arXiv220704542H',
#      'arXiv:2207.04542',
#      '10.1093/mnras/stad1244',
#      '2023MNRAS.tmp.1184H',
#      '10.48550/arXiv.2207.04542']},
#    {'bibcode': '2023ApJ...947...70D',
#     'identifier': ['2023ApJ...947...70D',
#      'arXiv:2211.02059',
#      '10.48550/arXiv.2211.02059',
#      '2022arXiv221102059D',
#      '10.3847/1538-4357/acc105']},
#    {'bibcode': '2023arXiv230303989P',
#     'identifier': ['2023arXiv230303989P',
#      '10.48550/arXiv.2303.03989',
#      'arXiv:2303.03989']},
#    {'bibcode': '2023arXiv230109865M',
#     'identifier': ['2023arXiv230109865M',
#      'arXiv:2301.09865',
#      '10.48550/arXiv.2301.09865']},
#    {'bibcode': '2023MNRAS.tmp.1133M',
#     'identifier': ['2023MNRAS.tmp.1133M',
#      '10.1093/mnras/stad1154',
#      '2023arXiv230206644M',
#      '10.48550/arXiv.2302.06644',
#      'arXiv:2302.06644']},
#    {'bibcode': '2001AnGeo..19.1197E',
#     'identifier': ['2001AnGeo..19.1197E', '10.5194/angeo-19-1197-2001']},
#    {'bibcode': '2004JFS....19..389S',
#     'identifier': ['10.1016/j.jfluidstructs.2004.02.005',
#      '2004JFS....19..389S']},
#    {'bibcode': '1977JLTP...29..301T',
#     'identifier': ['10.1007/BF00655097', '1977JLTP...29..301T']},
#    {'bibcode': '2013EnST...47.7137Z',
#     'identifier': ['10.1021/es401288x', '2013EnST...47.7137Z']},
#    {'bibcode': '2023A&A...672A.129C',
#     'identifier': ['10.1051/0004-6361/202245379',
#      '2023arXiv230203112C',
#      '2023A&A...672A.129C',
#      'arXiv:2302.03112',
#      '10.48550/arXiv.2302.03112']},
#    {'bibcode': '2023arXiv230501014S',
#     'identifier': ['10.48550/arXiv.2305.01014',
#      'arXiv:2305.01014',
#      '2023arXiv230501014S']},
#    {'bibcode': '2023ApJ...947L..31S',
#     'identifier': ['arXiv:2212.05070',
#      '2023ApJ...947L..31S',
#      '2022arXiv221205070S',
#      '10.48550/arXiv.2212.05070',
#      '10.3847/2041-8213/acc9b5']},
#    {'bibcode': '2022arXiv221002472R',
#     'identifier': ['10.48550/arXiv.2210.02472',
#      'arXiv:2210.02472',
#      '2022arXiv221002472R']},
#    {'bibcode': '2023A&A...671A.132S',
#     'identifier': ['10.48550/arXiv.2301.01065',
#      'arXiv:2301.01065',
#      '2023A&A...671A.132S',
#      '10.1051/0004-6361/202244846',
#      '2023arXiv230101065S']},
#    {'bibcode': '2023ApJ...947L..32Z',
#     'identifier': ['10.3847/2041-8213/accb5a',
#      'arXiv:2303.01349',
#      '10.48550/arXiv.2303.01349',
#      '2023ApJ...947L..32Z',
#      '2023arXiv230301349Z']},
#    {'bibcode': '2023arXiv230302263F',
#     'identifier': ['arXiv:2303.02263',
#      '2023arXiv230302263F',
#      '10.48550/arXiv.2303.02263']},
#    {'bibcode': '2023A&A...673L...2V',
#     'identifier': ['arXiv:2304.05777',
#      '10.1051/0004-6361/202346135',
#      '2023A&A...673L...2V',
#      '10.48550/arXiv.2304.05777',
#      '2023arXiv230405777V']},
#    {'bibcode': '2023MNRAS.522.2279R',
#     'identifier': ['arXiv:2304.06291',
#      '10.48550/arXiv.2304.06291',
#      '10.1093/mnras/stad1094',
#      '2023MNRAS.522.2279R',
#      '2023arXiv230406291R']},
#    {'bibcode': '2023ApJ...947L..26N',
#     'identifier': ['10.48550/arXiv.2207.13860',
#      'arXiv:2207.13860',
#      '2023ApJ...947L..26N',
#      '2022arXiv220713860N',
#      '10.3847/2041-8213/acbfb9']},
#    {'bibcode': '2023arXiv230413843K',
#     'identifier': ['10.48550/arXiv.2304.13843',
#      'arXiv:2304.13843',
#      '2023arXiv230413843K']},
#    {'bibcode': '2023ApJ...948....7D',
#     'identifier': ['10.48550/arXiv.2302.14347',
#      '10.3847/1538-4357/acbf54',
#      '2023ApJ...948....7D',
#      'arXiv:2302.14347',
#      '2023arXiv230214347D']},
#    {'bibcode': '2023arXiv230203105C',
#     'identifier': ['2023arXiv230203105C',
#      'arXiv:2302.03105',
#      '10.48550/arXiv.2302.03105']},
#    {'bibcode': '2022arXiv221214539K',
#     'identifier': ['10.48550/arXiv.2212.14539',
#      '2022arXiv221214539K',
#      'arXiv:2212.14539']},
#    {'bibcode': '2023RAA....23c5013L',
#     'identifier': ['2023arXiv230103068L',
#      '2023RAA....23c5013L',
#      'arXiv:2301.03068',
#      '10.48550/arXiv.2301.03068',
#      '10.1088/1674-4527/acb877']},
#    {'bibcode': '2002EnST...36.1169S',
#     'identifier': ['2002EnST...36.1169S', '10.1021/es0108077']},
#    {'bibcode': '2004AgFM..121...19J',
#     'identifier': ['2004AgFM..121...19J', '10.1016/j.agrformet.2003.08.027']},
#    {'bibcode': '2004Geop...69..231S',
#     'identifier': ['10.1190/1.1649391', '2004Geop...69..231S']},
#    {'bibcode': '2023arXiv230105166F',
#     'identifier': ['2023arXiv230105166F',
#      'arXiv:2301.05166',
#      '10.48550/arXiv.2301.05166']},
#    {'bibcode': '1996Oecol.108..583C',
#     'identifier': ['10.1007/BF00329030', '1996Oecol.108..583C']},
#    {'bibcode': '2023MNRAS.tmp.1139P',
#     'identifier': ['10.48550/arXiv.2301.07398',
#      '10.1093/mnras/stad1213',
#      '2023arXiv230107398P',
#      '2023MNRAS.tmp.1139P',
#      'arXiv:2301.07398']},
#    {'bibcode': '1995JVSTA..13.1553H',
#     'identifier': ['10.1116/1.579726',
#      '1995JVSTA..13.1553H',
#      '1995JVST...13.1553H']},
#    {'bibcode': '2023arXiv230207057P',
#     'identifier': ['arXiv:2302.07057',
#      '10.48550/arXiv.2302.07057',
#      '2023arXiv230207057P']},
#    {'bibcode': '2018EnST...52.1704A',
#     'identifier': ['2018EnST...52.1704A', '10.1021/acs.est.7b05559']},
#    {'bibcode': '2023A&A...673A..19E',
#     'identifier': ['10.1051/0004-6361/202245612',
#      'arXiv:2303.08205',
#      '10.48550/arXiv.2303.08205',
#      '2023arXiv230308205E',
#      '2023A&A...673A..19E']},
#    {'bibcode': '2018MNRAS.474.4514I',
#     'identifier': ['10.48550/arXiv.1711.11449',
#      '2017arXiv171111449I',
#      'arXiv:1711.11449',
#      '10.1093/mnras/stx3115',
#      '2018MNRAS.474.4514I']},
#    {'bibcode': '2023A&A...673A..25V',
#     'identifier': ['arXiv:2303.00291',
#      '2023arXiv230300291V',
#      '2023A&A...673A..25V',
#      '10.48550/arXiv.2303.00291',
#      '10.1051/0004-6361/202245418']},
#    {'bibcode': '2023MNRAS.tmp.1163R',
#     'identifier': ['arXiv:2301.03626',
#      '10.1093/mnras/stad1239',
#      '2023MNRAS.tmp.1163R',
#      '10.48550/arXiv.2301.03626',
#      '2023arXiv230103626R']},
#    {'bibcode': '2022ESC.....6..597M',
#     'identifier': ['2022ESC.....6..597M',
#      '10.1021/acsearthspacechem.1c00357',
#      '2022arXiv220107512M',
#      'arXiv:2201.07512',
#      '10.48550/arXiv.2201.07512']},
#    {'bibcode': '2022arXiv220909256G',
#     'identifier': ['10.48550/arXiv.2209.09256',
#      '2022arXiv220909256G',
#      'arXiv:2209.09256']},
#    {'bibcode': '2023arXiv230109652A',
#     'identifier': ['2023arXiv230109652A',
#      'arXiv:2301.09652',
#      '10.48550/arXiv.2301.09652']},
#    {'bibcode': '2023arXiv230310189J',
#     'identifier': ['10.48550/arXiv.2303.10189',
#      '2023arXiv230310189J',
#      'arXiv:2303.10189']},
#    {'bibcode': '2023ApJ...947...75K',
#     'identifier': ['2023ApJ...947...75K',
#      '2023arXiv230212848K',
#      'arXiv:2302.12848',
#      '10.3847/1538-4357/acbf30',
#      '10.48550/arXiv.2302.12848']},
#    {'bibcode': '2023arXiv230316204D',
#     'identifier': ['2023arXiv230316204D',
#      '10.48550/arXiv.2303.16204',
#      'arXiv:2303.16204']},
#    {'bibcode': '2023A&A...673A..16K',
#     'identifier': ['10.48550/arXiv.2303.10013',
#      'arXiv:2303.10013',
#      '10.1051/0004-6361/202346054',
#      '2023A&A...673A..16K',
#      '2023arXiv230310013K']},
#    {'bibcode': '2023arXiv230412028C',
#     'identifier': ['10.48550/arXiv.2304.12028',
#      '2023arXiv230412028C',
#      'arXiv:2304.12028']},
#    {'bibcode': '2023arXiv230202682P',
#     'identifier': ['10.48550/arXiv.2302.02682',
#      '2023arXiv230202682P',
#      'arXiv:2302.02682']},
#    {'bibcode': '2023A&A...673A..30P',
#     'identifier': ['2023arXiv230312845P',
#      '10.48550/arXiv.2303.12845',
#      '2023A&A...673A..30P',
#      '10.1051/0004-6361/202245769',
#      'arXiv:2303.12845']},
#    {'bibcode': '2023arXiv230501007V',
#     'identifier': ['10.48550/arXiv.2305.01007',
#      'arXiv:2305.01007',
#      '2023arXiv230501007V']},
#    {'bibcode': '2023arXiv230106779Z',
#     'identifier': ['10.48550/arXiv.2301.06779',
#      '2023arXiv230106779Z',
#      'arXiv:2301.06779']},
#    {'bibcode': '2023arXiv230501335Z',
#     'identifier': ['10.48550/arXiv.2305.01335',
#      '2023arXiv230501335Z',
#      'arXiv:2305.01335']},
#    {'bibcode': '2023arXiv230312530A',
#     'identifier': ['10.48550/arXiv.2303.12530',
#      '2023arXiv230312530A',
#      'arXiv:2303.12530']},
#    {'bibcode': '2023arXiv230501493W',
#     'identifier': ['10.48550/arXiv.2305.01493',
#      'arXiv:2305.01493',
#      '2023arXiv230501493W']},
#    {'bibcode': '2023arXiv230500999P',
#     'identifier': ['arXiv:2305.00999',
#      '10.48550/arXiv.2305.00999',
#      '2023arXiv230500999P']},
#    {'bibcode': '2003ChGeo.194....3B',
#     'identifier': ['10.1016/S0009-2541(02)00268-1', '2003ChGeo.194....3B']},
#    {'bibcode': '2023ESC.....7..260E',
#     'identifier': ['arXiv:2210.16921',
#      '2023ESC.....7..260E',
#      '10.1021/acsearthspacechem.1c00342',
#      '10.48550/arXiv.2210.16921',
#      '2022arXiv221016921E']},
#    {'bibcode': '2023arXiv230300770B',
#     'identifier': ['10.48550/arXiv.2303.00770',
#      'arXiv:2303.00770',
#      '2023arXiv230300770B']},
#    {'bibcode': '1985JVSTA...3.1502T',
#     'identifier': ['1985JVST....3.1502T',
#      '1985JVSTA...3.1502T',
#      '10.1116/1.573160']},
#    {'bibcode': '1986JVSTA...4.3059T',
#     'identifier': ['1986JVSTA...4.3059T',
#      '10.1116/1.573628',
#      '1986JVST....4.3059T']},
#    {'bibcode': '1996JAtC...24...57S',
#     'identifier': ['10.1007/BF00053823', '1996JAtC...24...57S']},
#    {'bibcode': '2023arXiv230214203C',
#     'identifier': ['2023arXiv230214203C',
#      '10.48550/arXiv.2302.14203',
#      'arXiv:2302.14203']},
#    {'bibcode': '2023MNRAS.tmp.1118S',
#     'identifier': ['2023MNRAS.tmp.1118S',
#      'arXiv:2304.03015',
#      '2023arXiv230403015S',
#      '10.1093/mnras/stad1127',
#      '10.48550/arXiv.2304.03015']},
#    {'bibcode': '2023MNRAS.tmpL..47D',
#     'identifier': ['arXiv:2304.08514',
#      '10.48550/arXiv.2304.08514',
#      '2023MNRAS.tmpL..47D',
#      '2023arXiv230408514D',
#      '10.1093/mnrasl/slad048']},
#    {'bibcode': '2023ApJ...947...67R',
#     'identifier': ['10.48550/arXiv.2210.09856',
#      '2022arXiv221009856R',
#      '10.3847/1538-4357/ac9b4e',
#      'arXiv:2210.09856',
#      '2023ApJ...947...67R']},
#    {'bibcode': '2022arXiv221116388C',
#     'identifier': ['arXiv:2211.16388',
#      '10.48550/arXiv.2211.16388',
#      '2022arXiv221116388C']},
#    {'bibcode': '2023MNRAS.519.5402Y',
#     'identifier': ['10.1093/mnras/stad048',
#      '2023MNRAS.tmp...61Y',
#      '2023MNRAS.519.5402Y',
#      '2023arXiv230413283Y',
#      '10.48550/arXiv.2304.13283',
#      'arXiv:2304.13283']},
#    {'bibcode': '2023arXiv230501627C',
#     'identifier': ['2023arXiv230501627C',
#      '10.48550/arXiv.2305.01627',
#      'arXiv:2305.01627']},
#    {'bibcode': '2023MNRAS.tmp.1127C',
#     'identifier': ['10.1093/mnras/stad1196',
#      '2023MNRAS.tmp.1127C',
#      '2023arXiv230209763C',
#      'arXiv:2302.09763',
#      '10.48550/arXiv.2302.09763']},
#    {'bibcode': '2023PhRvD.107d3502H',
#     'identifier': ['arXiv:2211.02651',
#      '2022arXiv221102651H',
#      '2023PhRvD.107d3502H',
#      '10.48550/arXiv.2211.02651',
#      '10.1103/PhysRevD.107.043502']},
#    {'bibcode': '2023arXiv230108271Z',
#     'identifier': ['arXiv:2301.08271',
#      '10.48550/arXiv.2301.08271',
#      '2023arXiv230108271Z']},
#    {'bibcode': '2023MNRAS.tmp.1164P',
#     'identifier': ['2023MNRAS.tmp.1164P',
#      '10.48550/arXiv.2304.10485',
#      '10.1093/mnras/stad1252',
#      '2023arXiv230410485P',
#      'arXiv:2304.10485']},
#    {'bibcode': '2014EnST...48.8334V',
#     'identifier': ['10.1021/es405118y', '2014EnST...48.8334V']},
#    {'bibcode': '1997JVSTA..15.1460R',
#     'identifier': ['10.1116/1.580562',
#      '1997JVSTA..15.1460R',
#      '1997JVST...15.1460R']},
#    {'bibcode': '1989Oecol..78....9E',
#     'identifier': ['1989Oecol..78....9E', '10.1007/BF00377192']},
#    {'bibcode': '2023JPhA...56s4001Z',
#     'identifier': ['2023JPhA...56s4001Z',
#      '10.1088/1751-8121/acc76f',
#      '2022arXiv220601758Z',
#      'arXiv:2206.01758',
#      '10.48550/arXiv.2206.01758']},
#    {'bibcode': '2020MNRAS.499.5656R',
#     'identifier': ['10.1093/mnras/staa3245',
#      '2020MNRAS.tmp.3025R',
#      '2020MNRAS.499.5656R',
#      '2020arXiv200609159R',
#      '10.48550/arXiv.2006.09159',
#      'arXiv:2006.09159']},
#    {'bibcode': '2016NanoL..16.7433L',
#     'identifier': ['2016NanoL..16.7433L',
#      '10.1021/acs.nanolett.6b03052',
#      'arXiv:1608.04169',
#      '10.48550/arXiv.1608.04169',
#      '2016arXiv160804169L']},
#    {'bibcode': '2023MNRAS.tmp.1198C',
#     'identifier': ['2023MNRAS.tmp.1198C',
#      '10.48550/arXiv.2304.03863',
#      '2023arXiv230403863C',
#      'arXiv:2304.03863',
#      '10.1093/mnras/stad1074']},
#    {'bibcode': '2023MNRAS.520.1005J',
#     'identifier': ['arXiv:2112.05543',
#      '10.1093/mnras/stad202',
#      '2023MNRAS.520.1005J',
#      '2023MNRAS.tmp..213J',
#      '2021arXiv211205543J',
#      '10.48550/arXiv.2112.05543']},
#    {'bibcode': '2023arXiv230500998S',
#     'identifier': ['arXiv:2305.00998',
#      '2023arXiv230500998S',
#      '10.48550/arXiv.2305.00998']},
#    {'bibcode': '2023arXiv230413044N',
#     'identifier': ['arXiv:2304.13044',
#      '10.48550/arXiv.2304.13044',
#      '2023arXiv230413044N']},
#    {'bibcode': '2023MNRAS.521.3727V',
#     'identifier': ['arXiv:2303.14016',
#      '2023MNRAS.521.3727V',
#      '10.48550/arXiv.2303.14016',
#      '2023arXiv230314016V',
#      '10.1093/mnras/stad678']},
#    {'bibcode': '2023arXiv230501075M',
#     'identifier': ['2023arXiv230501075M',
#      '10.48550/arXiv.2305.01075',
#      'arXiv:2305.01075']},
#    {'bibcode': '2023MNRAS.tmp.1174N',
#     'identifier': ['10.1093/mnras/stad1225',
#      '2023arXiv230411581N',
#      'arXiv:2304.11581',
#      '10.48550/arXiv.2304.11581',
#      '2023MNRAS.tmp.1174N']},
#    {'bibcode': '2023MNRAS.tmp.1168C',
#     'identifier': ['10.1093/mnras/stad1255',
#      '10.48550/arXiv.2210.15372',
#      '2022arXiv221015372C',
#      'arXiv:2210.15372',
#      '2023MNRAS.tmp.1168C']},
#    {'bibcode': '2022MNRAS.509.5046L',
#     'identifier': ['10.48550/arXiv.2106.04980',
#      '2022MNRAS.509.5046L',
#      '10.1093/mnras/stab3221',
#      'arXiv:2106.04980',
#      '2021arXiv210604980L',
#      '2021MNRAS.tmp.2968L']},
#    {'bibcode': '2023ApJS..266....4L',
#     'identifier': ['2023arXiv230400308L',
#      '10.48550/arXiv.2304.00308',
#      'arXiv:2304.00308',
#      '2023ApJS..266....4L',
#      '10.3847/1538-4365/acc395']},
#    {'bibcode': '2023arXiv230105401S',
#     'identifier': ['arXiv:2301.05401',
#      '2023arXiv230105401S',
#      '10.48550/arXiv.2301.05401']},
#    {'bibcode': '2023PhRvX..13b1014A',
#     'identifier': ['10.1103/PhysRevX.13.021014',
#      '2022arXiv220705189A',
#      '2023PhRvX..13b1014A',
#      'arXiv:2207.05189',
#      '10.48550/arXiv.2207.05189']},
#    {'bibcode': '2023A&A...673A..17M',
#     'identifier': ['10.48550/arXiv.2303.11948',
#      '10.1051/0004-6361/202346021',
#      '2023A&A...673A..17M',
#      '2023arXiv230311948M',
#      'arXiv:2303.11948']},
#    {'bibcode': '2023MNRAS.tmp.1130B',
#     'identifier': ['10.48550/arXiv.2304.03975',
#      '10.1093/mnras/stad1063',
#      '2023MNRAS.tmp.1130B',
#      '2023arXiv230403975B',
#      'arXiv:2304.03975']},
#    {'bibcode': '2023PASA...40...18M',
#     'identifier': ['arXiv:2304.00515',
#      '10.1017/pasa.2023.19',
#      '10.48550/arXiv.2304.00515',
#      '2023PASA...40...18M',
#      '2023arXiv230400515M']},
#    {'bibcode': '2023MNRAS.522.2495G',
#     'identifier': ['2023MNRAS.522.2495G',
#      '10.1093/mnras/stad1092',
#      '2023MNRAS.tmp.1072B',
#      '10.48550/arXiv.2212.13946',
#      'arXiv:2212.13946',
#      '2022arXiv221213946B']},
#    {'bibcode': '2023ApJ...947...77M',
#     'identifier': ['2023ApJ...947...77M',
#      'arXiv:2303.11209',
#      '10.48550/arXiv.2303.11209',
#      '2023arXiv230311209M',
#      '10.3847/1538-4357/acc5ed']},
#    {'bibcode': '2023JCAP...04..040A',
#     'identifier': ['2023arXiv230312855H',
#      '2023JCAP...04..040A',
#      'arXiv:2303.12855',
#      '10.48550/arXiv.2303.12855',
#      '10.1088/1475-7516/2023/04/040']},
#    {'bibcode': '2023ApJ...947L..29A',
#     'identifier': ['10.48550/arXiv.2303.15695',
#      '2023arXiv230315695A',
#      '2023ApJ...947L..29A',
#      'arXiv:2303.15695',
#      '10.3847/2041-8213/acc849']},
#    {'bibcode': '2023MNRAS.tmp.1205Y',
#     'identifier': ['10.1093/mnras/stad1224',
#      '10.48550/arXiv.2208.05491',
#      '2022arXiv220805491Y',
#      '2023MNRAS.tmp.1205Y',
#      'arXiv:2208.05491']},
#    {'bibcode': '1975JMatS..10.1049L',
#     'identifier': ['1975JMatS..10.1049L', '10.1007/BF00823224']},
#    {'bibcode': '2022arXiv220709540N',
#     'identifier': ['10.48550/arXiv.2207.09540',
#      'arXiv:2207.09540',
#      '2022arXiv220709540N']},
#    {'bibcode': '2019EnST...53.1039H',
#     'identifier': ['10.1021/acs.est.8b05297', '2019EnST...53.1039H']},
#    {'bibcode': '1984JVSTA...2..500M',
#     'identifier': ['1984JVST....2..500M',
#      '1984JVSTA...2..500M',
#      '10.1116/1.572604']},
#    {'bibcode': '2002Geo....30.1071G',
#     'identifier': ['2002Geo....30.1071G',
#      '10.1130/0091-7613(2002)030<1071:EFASBG>2.0.CO2']},
#    {'bibcode': '2016NanoL..16.1989K',
#     'identifier': ['2016NanoL..16.1989K', '10.1021/acs.nanolett.5b05263']},
#    {'bibcode': '2016NanoL..16.4903Z',
#     'identifier': ['10.1021/acs.nanolett.6b01459', '2016NanoL..16.4903Z']},
#    {'bibcode': '2003JFS....17...57N',
#     'identifier': ['10.1016/S0889-9746(02)00099-3', '2003JFS....17...57N']},
#    {'bibcode': '2023ApJ...947...60T',
#     'identifier': ['2023ApJ...947...60T',
#      '10.3847/1538-4357/acc737',
#      'arXiv:2301.05075',
#      '10.48550/arXiv.2301.05075',
#      '2023arXiv230105075T']},
#    {'bibcode': '2012JVSTA..30c0801G',
#     'identifier': ['10.1116/1.3691832', '2012JVSTA..30c0801G']},
#    {'bibcode': '1999JVSTA..17.2401V',
#     'identifier': ['1999JVSTA..17.2401V',
#      '10.1116/1.581977',
#      '1999JVST...17.2401V']},
#    {'bibcode': '2014MNRAS.445..778I',
#     'identifier': ['2014MNRAS.445..778I',
#      '10.1093/mnras/stu1771',
#      '2014arXiv1408.6953I',
#      '10.48550/arXiv.1408.6953',
#      'arXiv:1408.6953']},
#    {'bibcode': '1974ChGeo..14..285P',
#     'identifier': ['1974ChGeo..14..285P', '10.1016/0009-2541(74)90066-7']},
#    {'bibcode': '2023MNRAS.tmp.1166V',
#     'identifier': ['arXiv:2209.15066',
#      '10.48550/arXiv.2209.15066',
#      '2023MNRAS.tmp.1166V',
#      '2022arXiv220915066V',
#      '10.1093/mnras/stad1253']},
#    {'bibcode': '2023MNRAS.tmp.1148S',
#     'identifier': ['10.1093/mnras/stad1185',
#      '2023arXiv230409549S',
#      'arXiv:2304.09549',
#      '2023MNRAS.tmp.1148S',
#      '10.48550/arXiv.2304.09549']},
#    {'bibcode': '2023MNRAS.tmp.1149W',
#     'identifier': ['10.48550/arXiv.2301.13038',
#      '2023arXiv230113038W',
#      '10.1093/mnras/stad1126',
#      '2023MNRAS.tmp.1149W',
#      'arXiv:2301.13038']},
#    {'bibcode': '2023ApJ...945..145A',
#     'identifier': ['10.48550/arXiv.2011.03130',
#      '10.3847/1538-4357/acbe9c',
#      '2023ApJ...945..145A',
#      'arXiv:2011.03130',
#      '2020arXiv201103130A']},
#    {'bibcode': '2023arXiv230316121A',
#     'identifier': ['2023arXiv230316121A',
#      '10.48550/arXiv.2303.16121',
#      'arXiv:2303.16121']},
#    {'bibcode': '2023MNRAS.tmp.1173P',
#     'identifier': ['2023MNRAS.tmp.1173P',
#      '10.48550/arXiv.2304.12357',
#      'arXiv:2304.12357',
#      '10.1093/mnras/stad1229',
#      '2023arXiv230412357P']},
#    {'bibcode': '2023MNRAS.522.1987B',
#     'identifier': ['10.48550/arXiv.2302.04011',
#      '10.1093/mnras/stad463',
#      'arXiv:2302.04011',
#      '2023arXiv230204011B',
#      '2023MNRAS.522.1987B']},
#    {'bibcode': '2023arXiv230309959T',
#     'identifier': ['2023arXiv230309959T',
#      '10.48550/arXiv.2303.09959',
#      'arXiv:2303.09959']},
#    {'bibcode': '2023A&A...673A..26G',
#     'identifier': ['10.48550/arXiv.2303.04717',
#      'arXiv:2303.04717',
#      '2023arXiv230304717G',
#      '10.1051/0004-6361/202243681',
#      '2023A&A...673A..26G']},
#    {'bibcode': '2023MNRAS.521.3333L',
#     'identifier': ['10.48550/arXiv.2204.10835',
#      '2023MNRAS.521.3333L',
#      'arXiv:2204.10835',
#      '2022arXiv220410835L',
#      '10.1093/mnras/stac1220']},
#    {'bibcode': '2023MNRAS.tmp.1142D',
#     'identifier': ['2023arXiv230409642D',
#      '10.1093/mnras/stad1193',
#      '2023arXiv230409642J',
#      'arXiv:2304.09642',
#      '10.48550/arXiv.2304.09642',
#      '2023MNRAS.tmp.1142D']},
#    {'bibcode': '2023arXiv230104529P',
#     'identifier': ['2023arXiv230104529P',
#      '10.48550/arXiv.2301.04529',
#      'arXiv:2301.04529']},
#    {'bibcode': '2023arXiv230501000K',
#     'identifier': ['2023arXiv230501000K',
#      'arXiv:2305.01000',
#      '10.48550/arXiv.2305.01000']},
#    {'bibcode': '2023MNRAS.tmp.1135M',
#     'identifier': ['2023arXiv230111939M',
#      '10.48550/arXiv.2301.11939',
#      '10.1093/mnras/stad1182',
#      'arXiv:2301.11939',
#      '2023MNRAS.tmp.1135M']},
#    {'bibcode': '2023MNRAS.tmp.1146Z',
#     'identifier': ['arXiv:2304.07864',
#      '10.1093/mnras/stad1178',
#      '2023MNRAS.tmp.1146Z',
#      '10.48550/arXiv.2304.07864',
#      '2023arXiv230407864Z']},
#    {'bibcode': '2023arXiv230500993D',
#     'identifier': ['10.48550/arXiv.2305.00993',
#      'arXiv:2305.00993',
#      '2023arXiv230500993D']},
#    {'bibcode': '2023arXiv230501436P',
#     'identifier': ['2023arXiv230501436P',
#      '10.48550/arXiv.2305.01436',
#      'arXiv:2305.01436']},
#    {'bibcode': '2023MNRAS.tmp.1141Z',
#     'identifier': ['10.48550/arXiv.2304.11296',
#      '2023MNRAS.tmp.1141Z',
#      '10.1093/mnras/stad1215',
#      '2023arXiv230411296Z',
#      'arXiv:2304.11296']},
#    {'bibcode': '2023arXiv230500988T',
#     'identifier': ['arXiv:2305.00988',
#      '10.48550/arXiv.2305.00988',
#      '2023arXiv230500988T']},
#    {'bibcode': '2023arXiv230501582C',
#     'identifier': ['10.48550/arXiv.2305.01582',
#      'arXiv:2305.01582',
#      '2023arXiv230501582C']},
#    {'bibcode': '2023arXiv230500108C',
#     'identifier': ['2023arXiv230500108C',
#      'arXiv:2305.00108',
#      '10.48550/arXiv.2305.00108']},
#    {'bibcode': '2022arXiv220113274M',
#     'identifier': ['2022arXiv220113274M',
#      '10.48550/arXiv.2201.13274',
#      'arXiv:2201.13274']},
#    {'bibcode': '2004Geo....32..733D',
#     'identifier': ['10.1130/G20639.1', '2004Geo....32..733D']},
#    {'bibcode': '2003EnST...37..958M',
#     'identifier': ['10.1021/es0258879', '2003EnST...37..958M']},
#    {'bibcode': '1993EnST...27.1892R',
#     'identifier': ['1993EnST...27.1892R', '10.1021/es00046a019']},
#    {'bibcode': '2018NanoL..18.7658S',
#     'identifier': ['10.48550/arXiv.1808.06559',
#      'arXiv:1808.06559',
#      '10.1021/acs.nanolett.8b03321',
#      '2018NanoL..18.7658S',
#      '2018arXiv180806559S']},
#    {'bibcode': '2018NanoL..18.3125O',
#     'identifier': ['10.48550/arXiv.1802.08152',
#      '2018arXiv180208152O',
#      '10.1021/acs.nanolett.8b00683',
#      '2018NanoL..18.3125O',
#      'arXiv:1802.08152']},
#    {'bibcode': '2023RAA....23e5008Q',
#     'identifier': ['2023RAA....23e5008Q',
#      '10.48550/arXiv.2303.08344',
#      '10.1088/1674-4527/acc153',
#      '2023arXiv230308344Q',
#      'arXiv:2303.08344']},
#    {'bibcode': '1986JVSTA...4..689P',
#     'identifier': ['10.1116/1.573833',
#      '1986JVSTA...4..689P',
#      '1986JVST....4..689P']},
#    {'bibcode': '1987JVSTA...5.3287T',
#     'identifier': ['10.1116/1.574188',
#      '1987JVST....5.3287T',
#      '1987JVSTA...5.3287T']},
#    {'bibcode': '2023arXiv230304556L',
#     'identifier': ['arXiv:2303.04556',
#      '10.48550/arXiv.2303.04556',
#      '2023arXiv230304556L']},
#    {'bibcode': '2002JPet...43.1857H',
#     'identifier': ['10.1093/petrology/43.10.1857', '2002JPet...43.1857H']},
#    {'bibcode': '1988JVSTA...6.1783N',
#     'identifier': ['1988JVST....6.1783N',
#      '1988JVSTA...6.1783N',
#      '10.1116/1.575297']},
#    {'bibcode': '2004JPoSA..42.5301H',
#     'identifier': ['10.1002/pola.20366', '2004JPoSA..42.5301H']},
#    {'bibcode': '2013JVSTA..31e0825D',
#     'identifier': ['10.1116/1.4819316', '2013JVSTA..31e0825D']},
#    {'bibcode': '2011EnST...45.7954L',
#     'identifier': ['10.1021/es2011622', '2011EnST...45.7954L']},
#    {'bibcode': '2016NanoL..16.5319H',
#     'identifier': ['2015arXiv151109380H',
#      '10.48550/arXiv.1511.09380',
#      '2016NanoL..16.5319H',
#      'arXiv:1511.09380',
#      '10.1021/acs.nanolett.6b00555']},
#    {'bibcode': '1986JVSTA...4.2661H',
#     'identifier': ['10.1116/1.573700',
#      '1986JVST....4.2661H',
#      '1986JVSTA...4.2661H']},
#    {'bibcode': '2004JHyMe...5...64G',
#     'identifier': ['2004JHyMe...5...64G',
#      '10.1175/1525-7541(2004)005<0064:CCOTHC>2.0.CO2']},
#    {'bibcode': '1988QuRes..30...67C',
#     'identifier': ['10.1016/0033-5894(88)90088-9', '1988QuRes..30...67C']},
#    {'bibcode': '2007JVSTA..25.1317H',
#     'identifier': ['2007JVSTA..25.1317H', '10.1116/1.2764082']},
#    {'bibcode': '2017MNRAS.471..548I',
#     'identifier': ['2017MNRAS.471..548I',
#      'arXiv:1706.08769',
#      '2017arXiv170608769I',
#      '10.48550/arXiv.1706.08769',
#      '10.1093/mnras/stx1629']},
#    {'bibcode': '2018MNRAS.473.1956I',
#     'identifier': ['10.48550/arXiv.1709.00202',
#      'arXiv:1709.00202',
#      '10.1093/mnras/stx2478',
#      '2017arXiv170900202I',
#      '2018MNRAS.473.1956I']},
#    {'bibcode': '2023arXiv230501250A',
#     'identifier': ['arXiv:2305.01250',
#      '2023arXiv230501250A',
#      '10.48550/arXiv.2305.01250']},
#    {'bibcode': '2023AJ....165..213P',
#     'identifier': ['10.48550/arXiv.2303.09259',
#      '2023AJ....165..213P',
#      '2023arXiv230309259P',
#      '10.3847/1538-3881/acc6d1',
#      'arXiv:2303.09259']},
#    {'bibcode': '2023MNRAS.521.4462D',
#     'identifier': ['10.1093/mnras/stad851',
#      '10.48550/arXiv.2303.16049',
#      '2023arXiv230316049D',
#      '2023MNRAS.521.4462D',
#      'arXiv:2303.16049']},
#    {'bibcode': '2022ApJS..260....2G',
#     'identifier': ['arXiv:2009.07927',
#      '2022ApJS..260....2G',
#      '10.48550/arXiv.2009.07927',
#      '10.3847/1538-4365/ac5969',
#      '2020arXiv200907927G']},
#    {'bibcode': '2021MNRAS.503.1276M',
#     'identifier': ['10.48550/arXiv.2102.05353',
#      'arXiv:2102.05353',
#      '2021MNRAS.503.1276M',
#      '10.1093/mnras/stab438',
#      '2021arXiv210205353M']},
#    {'bibcode': '2023MNRAS.tmp.1183R',
#     'identifier': ['10.48550/arXiv.2304.13057',
#      '2023MNRAS.tmp.1183R',
#      '2023arXiv230413057R',
#      'arXiv:2304.13057',
#      '10.1093/mnras/stad1264']},
#    {'bibcode': '2023A&A...673A..21E',
#     'identifier': ['10.48550/arXiv.2303.09984',
#      'arXiv:2303.09984',
#      '2023arXiv230309984E',
#      '2023A&A...673A..21E',
#      '10.1051/0004-6361/202245206']},
#    {'bibcode': '2023arXiv230501533M',
#     'identifier': ['2023arXiv230501533M',
#      'arXiv:2305.01533',
#      '10.48550/arXiv.2305.01533']},
#    {'bibcode': '2023PhRvD.107h3528N',
#     'identifier': ['arXiv:2207.12383',
#      '2022arXiv220712383N',
#      '10.48550/arXiv.2207.12383',
#      '2023PhRvD.107h3528N',
#      '10.1103/PhysRevD.107.083528']},
#    {'bibcode': '2023MNRAS.tmp.1134C',
#     'identifier': ['arXiv:2304.08129',
#      '2023arXiv230408129C',
#      '10.1093/mnras/stad1204',
#      '2023MNRAS.tmp.1134C',
#      '10.48550/arXiv.2304.08129']},
#    {'bibcode': '2023AJ....165..211R',
#     'identifier': ['10.48550/arXiv.2304.03248',
#      'arXiv:2304.03248',
#      '2023AJ....165..211R',
#      '2023arXiv230403248R',
#      '10.3847/1538-3881/acc654']},
#    {'bibcode': '2023MNRAS.tmp.1188C',
#     'identifier': ['arXiv:2304.10886',
#      '2023MNRAS.tmp.1188C',
#      '2023arXiv230410886C',
#      '10.1093/mnras/stad1214',
#      '10.48550/arXiv.2304.10886']},
#    {'bibcode': '2023MNRAS.tmp.1199G',
#     'identifier': ['2023arXiv230412661G',
#      '10.1093/mnras/stad1258',
#      '10.48550/arXiv.2304.12661',
#      'arXiv:2304.12661',
#      '2023MNRAS.tmp.1199G']},
#    {'bibcode': '2023MNRAS.tmp.1138R',
#     'identifier': ['2023arXiv230106398R',
#      '10.48550/arXiv.2301.06398',
#      '2023MNRAS.tmp.1138R',
#      'arXiv:2301.06398',
#      '10.1093/mnras/stad1186']},
#    {'bibcode': '2023arXiv230501042G',
#     'identifier': ['10.48550/arXiv.2305.01042',
#      'arXiv:2305.01042',
#      '2023arXiv230501042G']},
#    {'bibcode': '2002EnST...36.1245L',
#     'identifier': ['10.1021/es0111941', '2002EnST...36.1245L']},
#    {'bibcode': '2012EnST...46.2006I',
#     'identifier': ['2012EnST...46.2006I', '10.1021/es2043504']},
#    {'bibcode': '1995JVSTA..13..368L',
#     'identifier': ['10.1116/1.579366',
#      '1995JVST...13..368L',
#      '1995JVSTA..13..368L']},
#    {'bibcode': '2023PhRvD.107h3029B',
#     'identifier': ['2023PhRvD.107h3029B',
#      '2023arXiv230110019B',
#      'arXiv:2301.10019',
#      '10.48550/arXiv.2301.10019',
#      '10.1103/PhysRevD.107.083029']},
#    {'bibcode': '2023PhRvX..13b1009Z',
#     'identifier': ['10.48550/arXiv.2210.13482',
#      '2022arXiv221013482Z',
#      '10.1103/PhysRevX.13.021009',
#      '2023PhRvX..13b1009Z',
#      'arXiv:2210.13482']},
#    {'bibcode': '2020EnST...54.3064L',
#     'identifier': ['2020EnST...54.3064L', '10.1021/acs.est.9b07082']},
#    {'bibcode': '1996EnST...30..422R',
#     'identifier': ['10.1021/es950057z', '1996EnST...30..422R']},
#    {'bibcode': '2015EnST...49..750Z',
#     'identifier': ['2015EnST...49..750Z', '10.1021/es5047099']},
#    {'bibcode': '2012EnST...46.2242W',
#     'identifier': ['2012EnST...46.2242W', '10.1021/es204168d']},
#    {'bibcode': '2017EnST...51.2508W',
#     'identifier': ['10.1021/acs.est.6b04806', '2017EnST...51.2508W']},
#    {'bibcode': '1998PreR...91..143H',
#     'identifier': ['1998PreR...91..143H', '10.1016/S0301-9268(98)00042-4']},
#    {'bibcode': '1998PreR...91..181D',
#     'identifier': ['10.1016/S0301-9268(98)00043-6', '1998PreR...91..181D']},
#    {'bibcode': '2004AgFM..123...79X',
#     'identifier': ['10.1016/j.agrformet.2003.10.004', '2004AgFM..123...79X']},
#    {'bibcode': '2015EnST...49.1130C',
#     'identifier': ['2015EnST...49.1130C', '10.1021/es504525u']},
#    {'bibcode': '2017EnST...51.4368S',
#     'identifier': ['2017EnST...51.4368S', '10.1021/acs.est.6b06155']},
#    {'bibcode': '2012JVSTA..30d0802D',
#     'identifier': ['2012JVSTA..30d0802D', '10.1116/1.4728205']},
#    {'bibcode': '1992JAtC...14..315B',
#     'identifier': ['10.1007/BF00115242', '1992JAtC...14..315B']},
#    {'bibcode': '2002JMP....43.4537C',
#     'identifier': ['10.1063/1.1494475',
#      '2002JMP....43.4537C',
#      '2001quant.ph..4088C',
#      '2002JMPS...43.4537C',
#      '10.48550/arXiv.quant-ph/0104088',
#      'arXiv:quant-ph/0104088']},
#    {'bibcode': '2004AgFM..126..237B',
#     'identifier': ['10.1016/j.agrformet.2004.06.011', '2004AgFM..126..237B']},
#    {'bibcode': '2011JVSTA..29e0801P',
#     'identifier': ['2011JVSTA..29e0801P', '10.1116/1.3609974']},
#    {'bibcode': '2023arXiv230501431N',
#     'identifier': ['arXiv:2305.01431',
#      '10.48550/arXiv.2305.01431',
#      '2023arXiv230501431N']},
#    {'bibcode': '2023MNRAS.tmp.1159C',
#     'identifier': ['10.48550/arXiv.2208.05218',
#      'arXiv:2208.05218',
#      '10.1093/mnras/stad1207',
#      '2022arXiv220805218C',
#      '2023MNRAS.tmp.1159C']},
#    {'bibcode': '2023ApJ...948....8L',
#     'identifier': ['arXiv:2302.10466',
#      '2023arXiv230210466L',
#      '10.3847/1538-4357/acbd99',
#      '2023ApJ...948....8L',
#      '10.48550/arXiv.2302.10466']},
#    {'bibcode': '2022arXiv220808808P',
#     'identifier': ['10.48550/arXiv.2208.08808',
#      '2022arXiv220808808P',
#      'arXiv:2208.08808']},
#    {'bibcode': '2023arXiv230501307A',
#     'identifier': ['arXiv:2305.01307',
#      '10.48550/arXiv.2305.01307',
#      '2023arXiv230501307A']},
#    {'bibcode': '2022arXiv220109915G',
#     'identifier': ['arXiv:2201.09915',
#      '10.48550/arXiv.2201.09915',
#      '2022arXiv220109915G']},
#    {'bibcode': '2023arXiv230501562W',
#     'identifier': ['arXiv:2305.01562',
#      '2023arXiv230501562W',
#      '10.48550/arXiv.2305.01562']},
#    {'bibcode': '2023MNRAS.522.2393S',
#     'identifier': ['10.1093/mnras/stad378',
#      '2023arXiv230413779S',
#      '2023MNRAS.522.2393S',
#      '10.48550/arXiv.2304.13779',
#      'arXiv:2304.13779',
#      '2023MNRAS.tmp..416S']},
#    {'bibcode': '2023PhRvD.107h3522F',
#     'identifier': ['2023arXiv230211579F',
#      '10.48550/arXiv.2302.11579',
#      '2023PhRvD.107h3522F',
#      '10.1103/PhysRevD.107.083522',
#      'arXiv:2302.11579']},
#    {'bibcode': '2023PhPl...30d0502V',
#     'identifier': ['10.48550/arXiv.2303.15351',
#      '2023arXiv230315351V',
#      '10.1063/5.0141512',
#      '2023PhPl...30d0502V',
#      'arXiv:2303.15351']},
#    {'bibcode': '2023MNRAS.tmp.1140A',
#     'identifier': ['10.48550/arXiv.2304.09295',
#      '10.1093/mnras/stad1199',
#      'arXiv:2304.09295',
#      '2023arXiv230409295A',
#      '2023MNRAS.tmp.1140A']},
#    {'bibcode': '2023MNRAS.tmp.1197F',
#     'identifier': ['2023MNRAS.tmp.1197F',
#      '2023arXiv230412705F',
#      'arXiv:2304.12705',
#      '10.1093/mnras/stad1257',
#      '10.48550/arXiv.2304.12705']},
#    {'bibcode': '2023arXiv230501594Y',
#     'identifier': ['10.48550/arXiv.2305.01594',
#      '2023arXiv230501594Y',
#      'arXiv:2305.01594']},
#    {'bibcode': '2015NanoL..15..339W',
#     'identifier': ['10.48550/arXiv.1409.4518',
#      '10.1021/nl503636c',
#      '2014arXiv1409.4518W',
#      '2015NanoL..15..339W',
#      'arXiv:1409.4518']},
#    {'bibcode': '2002ApMRv..55....1L',
#     'identifier': ['10.1115/1.1431547', '2002ApMRv..55....1L']},
#    {'bibcode': '2004PreR..134..349L',
#     'identifier': ['10.1016/j.precamres.2004.07.002', '2004PreR..134..349L']},
#    {'bibcode': '2017NanoL..17.5508Z',
#     'identifier': ['2017NanoL..17.5508Z',
#      '10.48550/arXiv.1708.09049',
#      'arXiv:1708.09049',
#      '10.1021/acs.nanolett.7b02198',
#      '2017arXiv170809049Z']},
#    {'bibcode': '2014EnST...48.6309L',
#     'identifier': ['2014EnST...48.6309L', '10.1021/es500362a']},
#    {'bibcode': '1978TSF....49....3L',
#     'identifier': ['10.1016/0040-6090(78)90309-7', '1978TSF....49....3L']},
#    {'bibcode': '2015EnST...49.8057A',
#     'identifier': ['2015EnST...49.8057A', '10.1021/acs.est.5b01236']},
#    {'bibcode': '1998EnST...32.2197W',
#     'identifier': ['10.1021/es9708530', '1998EnST...32.2197W']},
#    {'bibcode': '2023PhRvL.130p1003L',
#     'identifier': ['2023PhRvL.130p1003L',
#      '10.1103/PhysRevLett.130.161003',
#      '10.48550/arXiv.2212.04494',
#      'arXiv:2212.04494',
#      '2022arXiv221204494L']},
#    {'bibcode': '2016NanoL..16.5235W',
#     'identifier': ['2016NanoL..16.5235W', '10.1021/acs.nanolett.6b02326']},
#    {'bibcode': '1987JFS.....1..239Z',
#     'identifier': ['10.1016/S0889-9746(87)90355-0', '1987JFS.....1..239Z']},
#    {'bibcode': '1984ClCh....6..287M',
#     'identifier': ['1984ClCh....6..287M', '10.1007/BF00142477']},
#    {'bibcode': '2022arXiv220710124S',
#     'identifier': ['2022arXiv220710124S',
#      'arXiv:2207.10124',
#      '10.48550/arXiv.2207.10124']},
#    {'bibcode': '1998EnST...32...13R',
#     'identifier': ['10.1021/es960930b', '1998EnST...32...13R']},
#    {'bibcode': '2004IJRS...25.3999M',
#     'identifier': ['2004IJRS...25.3999M', '10.1080/01431160310001654923']},
#    {'bibcode': '1989JVSTA...7.2758S',
#     'identifier': ['10.1116/1.576175',
#      '1989JVSTA...7.2758S',
#      '1989JVST....7.2758S']},
#    {'bibcode': '2016JLwT...34..157K',
#     'identifier': ['2016JLwT...34..157K', '10.1109/JLT.2015.2463719']},
#    {'bibcode': '2003IJSEd..25..671D',
#     'identifier': ['10.1080/09500690305016', '2003IJSEd..25..671D']},
#    {'bibcode': '2004ApGC...19..181A',
#     'identifier': ['10.1016/j.apgeochem.2003.09.006', '2004ApGC...19..181A']},
#    {'bibcode': '2001JMetG..19..291S',
#     'identifier': ['2001JMetG..19..291S', '10.1046/j.0263-4929.2000.00312.x']},
#    {'bibcode': '2023ApJ...947...71A',
#     'identifier': ['arXiv:2303.03431',
#      '2023arXiv230303431A',
#      '10.3847/1538-4357/acc186',
#      '10.48550/arXiv.2303.03431',
#      '2023ApJ...947...71A']},
#    {'bibcode': '2023A&A...673A..12Z',
#     'identifier': ['2023A&A...673A..12Z',
#      'arXiv:2303.14394',
#      '10.1051/0004-6361/202245405',
#      '10.48550/arXiv.2303.14394',
#      '2023arXiv230314394Z']},
#    {'bibcode': '1998MSRv...17..337Z',
#     'identifier': ['10.1002/(SICI)1098-2787(1998)17:5<337::AID-MAS2>3.0.CO2-S',
#      '1998MSRv...17..337Z']},
#    {'bibcode': '2023arXiv230412938C',
#     'identifier': ['arXiv:2304.12938',
#      '10.48550/arXiv.2304.12938',
#      '2023arXiv230412938C']},
#    {'bibcode': '2022ESC.....6..455L',
#     'identifier': ['2022arXiv220209640L',
#      '2022ESC.....6..455L',
#      'arXiv:2202.09640',
#      '10.48550/arXiv.2202.09640',
#      '10.1021/acsearthspacechem.1c00330']},
#    {'bibcode': '2023A&A...673A...6D',
#     'identifier': ['2023A&A...673A...6D',
#      'arXiv:2211.05900',
#      '2022arXiv221105900D',
#      '10.1051/0004-6361/202243586',
#      '10.48550/arXiv.2211.05900']},
#    {'bibcode': '2017NanoL..17.2703L',
#     'identifier': ['10.48550/arXiv.1702.04616',
#      '2017arXiv170204616L',
#      '10.1021/acs.nanolett.7b00649',
#      '2017NanoL..17.2703L',
#      'arXiv:1702.04616']},
#    {'bibcode': '2023arXiv230309501F',
#     'identifier': ['10.48550/arXiv.2303.09501',
#      'arXiv:2303.09501',
#      '2023arXiv230309501F']},
#    {'bibcode': '2023MNRAS.tmp.1169G',
#     'identifier': ['2023MNRAS.tmp.1169G',
#      'arXiv:2302.11158',
#      '2023arXiv230211158G',
#      '10.1093/mnras/stad1238',
#      '10.48550/arXiv.2302.11158']},
#    {'bibcode': '2023arXiv230501312N',
#     'identifier': ['arXiv:2305.01312',
#      '10.48550/arXiv.2305.01312',
#      '2023arXiv230501312N']},
#    {'bibcode': '2023arXiv230312011A',
#     'identifier': ['2023arXiv230312011A',
#      'arXiv:2303.12011',
#      '10.48550/arXiv.2303.12011']},
#    {'bibcode': '2023PhRvL.130r6701W',
#     'identifier': ['arXiv:2203.02518',
#      '10.1103/PhysRevLett.130.186701',
#      '2022arXiv220302518W',
#      '2023PhRvL.130r6701W',
#      '10.48550/arXiv.2203.02518']},
#    {'bibcode': '2023MNRAS.tmp.1131L',
#     'identifier': ['2023MNRAS.tmp.1131L',
#      '10.48550/arXiv.2206.02129',
#      'arXiv:2206.02129',
#      '2022arXiv220602129L',
#      '10.1093/mnras/stad1168']},
# ...
#    {'bibcode': '1998BasR...10..441L',
#     'identifier': ['10.1046/j.1365-2117.1998.00080.x', '1998BasR...10..441L']},
#    {'bibcode': '1997JVSTA..15..610C',
#     'identifier': ['10.1116/1.580692',
#      '1997JVSTA..15..610C',
#      '1997JVST...15..610C']},
#    {'bibcode': '2016NanoL..16.7376P',
#     'identifier': ['10.1021/acs.nanolett.6b02772', '2016NanoL..16.7376P']},
#    {'bibcode': '2017NanoL..17.5133L',
#     'identifier': ['10.1021/acs.nanolett.7b02518', '2017NanoL..17.5133L']},
#    {'bibcode': '1998JVSTA..16..278P',
#     'identifier': ['1998JVST...16..278P',
#      '1998JVSTA..16..278P',
#      '10.1116/1.580983']},
#    {'bibcode': '2002MGeol.192...23N',
#     'identifier': ['10.1016/S0025-3227(02)00548-0', '2002MGeol.192...23N']},
#    {'bibcode': '2018NanoL..18.2420S',
#     'identifier': ['2018NanoL..18.2420S', '10.1021/acs.nanolett.7b05458']},
#    {'bibcode': '2017EnST...51.3260J',
#     'identifier': ['10.1021/acs.est.6b05761', '2017EnST...51.3260J']},
#    {'bibcode': '2003MarMP..48...49P',
#     'identifier': ['10.1016/S0377-8398(02)00160-3', '2003MarMP..48...49P']},
#    {'bibcode': '2000JPet...41.1207S',
#     'identifier': ['2000JPet...41.1207S', '10.1093/petrology/41.8.1207']},
#    {'bibcode': '2017NanoL..17.2895F',
#     'identifier': ['10.1021/acs.nanolett.7b00064', '2017NanoL..17.2895F']},
#    {'bibcode': '2014JVSTA..32b0603M',
#     'identifier': ['2014JVSTA..32b0603M', '10.1116/1.4843575']},
#    {'bibcode': '2019APS..DNP.LN009R', 'identifier': ['2019APS..DNP.LN009R']},
#    {'bibcode': '2022ConSc..34....1Z',
#     'identifier': ['10.48550/arXiv.2102.01375',
#      '2021arXiv210201375Z',
#      'arXiv:2102.01375',
#      '10.1080/09540091.2021.1936455',
#      '2022ConSc..34....1Z']},
#    {'bibcode': '2014EnST...48..104M',
#     'identifier': ['2014EnST...48..104M', '10.1021/es403646x']},
#    {'bibcode': '2002ScTEn.292...33M',
#     'identifier': ['2002ScTEn.292...33M', '10.1016/S0048-9697(02)00031-1']},
#    {'bibcode': '2016NanoL..16..497J',
#     'identifier': ['2015arXiv151203451J',
#      '10.48550/arXiv.1512.03451',
#      '10.1021/acs.nanolett.5b04141',
#      'arXiv:1512.03451',
#      '2016NanoL..16..497J']},
#    {'bibcode': '2017NanoL..17.4619H',
#     'identifier': ['2017arXiv170307062H',
#      '2017NanoL..17.4619H',
#      '10.48550/arXiv.1703.07062',
#      'arXiv:1703.07062',
#      '10.1021/acs.nanolett.7b01029']},
#    {'bibcode': '2016EnST...5010297R',
#     'identifier': ['2016EnST...5010297R', '10.1021/acs.est.6b02155']},
#    {'bibcode': '2011EnST...45.6237C',
#     'identifier': ['10.1021/es2021318', '2011EnST...45.6237C']},
#    {'bibcode': '2016EnST...50.3119F',
#     'identifier': ['2016EnST...50.3119F', '10.1021/acs.est.5b05974']},
#    {'bibcode': '2012EnST...46.1590P',
#     'identifier': ['2012EnST...46.1590P', '10.1021/es203836f']},
#    {'bibcode': '2013JVSTA..31e0801P',
#     'identifier': ['10.1116/1.4799504', '2013JVSTA..31e0801P']},
#    {'bibcode': '2011EnST...45.2818P',
#     'identifier': ['2011EnST...45.2818P', '10.1021/es2000694']},
#    {'bibcode': '2015NanoL..15..248M',
#     'identifier': ['2015NanoL..15..248M', '10.1021/nl503494y']},
#    {'bibcode': '2015EnST...4912271J',
#     'identifier': ['10.1021/acs.est.5b03521', '2015EnST...4912271J']},
#    {'bibcode': '2016MNRAS.462.4427I',
#     'identifier': ['10.1093/mnras/stw1973',
#      '2016MNRAS.462.4427I',
#      'arXiv:1608.01523',
#      '10.48550/arXiv.1608.01523',
#      '2016arXiv160801523I',
#      '2016MNRAS.tmp.1087I']},
#    {'bibcode': '2017NanoL..17.3452L',
#     'identifier': ['2017NanoL..17.3452L', '10.1021/acs.nanolett.7b00379']},
#    {'bibcode': '2017NanoL..17.3493H',
#     'identifier': ['2017arXiv170902004H',
#      '10.1021/acs.nanolett.7b00560',
#      'arXiv:1709.02004',
#      '2017NanoL..17.3493H',
#      '10.48550/arXiv.1709.02004']},
#    {'bibcode': '2000EnST...34..218H',
#     'identifier': ['2000EnST...34..218H', '10.1021/es9906958']},
#    {'bibcode': '1992IJNLM..27..503W',
#     'identifier': ['1992IJNLM..27..503W', '10.1016/0020-7462(92)90016-Z']},
#    {'bibcode': '1980Oecol..45..377M',
#     'identifier': ['10.1007/BF00540209', '1980Oecol..45..377M']},
#    {'bibcode': '1998JVSTA..16.3190D',
#     'identifier': ['1998JVST...16.3190D',
#      '1998JVSTA..16.3190D',
#      '10.1116/1.581519']},
#    {'bibcode': '2012NanoL..12.2088M',
#     'identifier': ['2012NanoL..12.2088M', '10.1021/nl300351j']},
#    {'bibcode': '1996JVSTA..14.2220P',
#     'identifier': ['1996JVST...14.2220P',
#      '1996JVSTA..14.2220P',
#      '10.1116/1.580050']},
#    {'bibcode': '1986EnST...20..195C',
#     'identifier': ['1986EnST...20..195C', '10.1021/es00144a015']},
#    {'bibcode': '1982Oecol..53....7B',
#     'identifier': ['1982Oecol..53....7B', '10.1007/BF00377129']},
#    {'bibcode': '1998JVSTA..16..270K',
#     'identifier': ['1998JVSTA..16..270K',
#      '1998JVST...16..270K',
#      '10.1116/1.580982']},
#    {'bibcode': '1986JVSTA...4..490M',
#     'identifier': ['10.1116/1.573866',
#      '1986JVST....4..490M',
#      '1986JVSTA...4..490M']},
#    {'bibcode': '2016EnST...5010134L',
#     'identifier': ['10.1021/acs.est.6b02079', '2016EnST...5010134L']},
#    {'bibcode': '2015MNRAS.451.2251I',
#     'identifier': ['2015arXiv150505853I',
#      '2015MNRAS.451.2251I',
#      '10.1093/mnras/stv1115',
#      'arXiv:1505.05853',
#      '10.48550/arXiv.1505.05853']},
#    {'bibcode': '2017NanoL..17.2690G',
#     'identifier': ['10.1021/acs.nanolett.7b00540',
#      '10.48550/arXiv.1702.02578',
#      '2017arXiv170202578G',
#      'arXiv:1702.02578',
#      '2017NanoL..17.2690G']},
#    {'bibcode': '1992JVSTA..10.1389C',
#     'identifier': ['10.1116/1.578256',
#      '1992JVSTA..10.1389C',
#      '1992JVST...10.1389C']},
#    {'bibcode': '2016NanoL..16.5866D',
#     'identifier': ['10.1021/acs.nanolett.6b02688', '2016NanoL..16.5866D']},
#    {'bibcode': '2001EnST...35.3344B',
#     'identifier': ['2001EnST...35.3344B', '10.1021/es001946b']},
#    {'bibcode': '2002EnST...36..747Z',
#     'identifier': ['2002EnST...36..747Z', '10.1021/es015619v']},
#    {'bibcode': '2002MGeol.190..493Y',
#     'identifier': ['2002MGeol.190..493Y', '10.1016/S0025-3227(02)00360-2']},
#    {'bibcode': '2003Geop...68..705W',
#     'identifier': ['2003Geop...68..705W', '10.1190/1.1567241']},
#    {'bibcode': '2001JVSTA..19..524Z',
#     'identifier': ['2001JVSTA..19..524Z',
#      '10.1116/1.1349728',
#      '2001JVST...19..524Z']},
#    {'bibcode': '2014EnST...4810242H',
#     'identifier': ['2014EnST...4810242H', '10.1021/es501337j']},
#    {'bibcode': '2023ESC.....7..156Q',
#     'identifier': ['arXiv:2301.04103',
#      '2023ESC.....7..156Q',
#      '2023arXiv230104103Q',
#      '10.48550/arXiv.2301.04103',
#      '10.1021/acsearthspacechem.2c00274']},
#    {'bibcode': '1993JVSTA..11.2487K',
#     'identifier': ['10.1116/1.578597',
#      '1993JVST...11.2487K',
#      '1993JVSTA..11.2487K']},
#    {'bibcode': '2018NanoL..18.6725R',
#     'identifier': ['10.1021/acs.nanolett.8b02387',
#      '2018arXiv180207317R',
#      'arXiv:1802.07317',
#      '10.48550/arXiv.1802.07317',
#      '2018NanoL..18.6725R']},
#    {'bibcode': '2016NanoL..16..555M',
#     'identifier': ['2016NanoL..16..555M', '10.1021/acs.nanolett.5b04221']},
#    {'bibcode': '2016EnST...50.1322F',
#     'identifier': ['2016EnST...50.1322F', '10.1021/acs.est.5b03965']},
#    {'bibcode': '2012EnST...46.1536K',
#     'identifier': ['2012EnST...46.1536K', '10.1021/es203495d']},
#    {'bibcode': '1988JVSTA...6.1778A',
#     'identifier': ['1988JVST....6.1778A',
#      '10.1116/1.575296',
#      '1988JVSTA...6.1778A']},
#    {'bibcode': '1989JVSTA...7..701P',
#     'identifier': ['1989JVST....7..701P',
#      '10.1116/1.575869',
#      '1989JVSTA...7..701P']},
#    {'bibcode': '2015NanoL..15...80L',
#     'identifier': ['2015NanoL..15...80L', '10.1021/nl502997v']},
#    {'bibcode': '1994JVSTA..12..323O',
#     'identifier': ['1994JVSTA..12..323O',
#      '10.1116/1.578876',
#      '1994JVST...12..323O']},
#    {'bibcode': '2014EnST...48.9391X',
#     'identifier': ['10.1021/es5021058', '2014EnST...48.9391X']},
#    {'bibcode': '2012EnST...46.2033A',
#     'identifier': ['10.1021/es202942q', '2012EnST...46.2033A']},
#    {'bibcode': '2016NanoL..16.4862Y',
#     'identifier': ['2016NanoL..16.4862Y', '10.1021/acs.nanolett.6b01255']},
#    {'bibcode': '2017EnST...5114283L',
#     'identifier': ['10.1021/acs.est.7b03055', '2017EnST...5114283L']},
#    {'bibcode': '2016NanoL..16.1848L',
#     'identifier': ['10.1021/acs.nanolett.5b04929', '2016NanoL..16.1848L']},
#    {'bibcode': '2019EnST...5310612L',
#     'identifier': ['10.1021/acs.est.9b03427', '2019EnST...5310612L']},
#    {'bibcode': '2017EnST...5111288H',
#     'identifier': ['2017EnST...5111288H', '10.1021/acs.est.7b03014']},
#    {'bibcode': '1989JVSTA...7..883A',
#     'identifier': ['1989JVSTA...7..883A',
#      '10.1116/1.575815',
#      '1989JVST....7..883A']},
#    {'bibcode': '2020EnST...54.2210X',
#     'identifier': ['2020EnST...54.2210X', '10.1021/acs.est.9b04850']},
#    {'bibcode': '1984Oecol..63...90W',
#     'identifier': ['10.1007/BF00379790', '1984Oecol..63...90W']},
#    {'bibcode': '2023PhRvD.107g4506A',
#     'identifier': ['10.1103/PhysRevD.107.074506',
#      '2022arXiv220615084A',
#      '2023PhRvD.107g4506A',
#      '10.48550/arXiv.2206.15084',
#      'arXiv:2206.15084']},
#    {'bibcode': '2023arXiv230501487A',
#     'identifier': ['2023arXiv230501487A',
#      'arXiv:2305.01487',
#      '10.48550/arXiv.2305.01487']},
#    {'bibcode': '2023arXiv230501149Y',
#     'identifier': ['arXiv:2305.01149',
#      '10.48550/arXiv.2305.01149',
#      '2023arXiv230501149Y']},
#    {'bibcode': '2023AN....34420113U',
#     'identifier': ['arXiv:2301.05870',
#      '10.1002/asna.20220113',
#      '2023arXiv230105870U',
#      '2023AN....34420113U',
#      '10.48550/arXiv.2301.05870']},
#    {'bibcode': '2023arXiv230501150B',
#     'identifier': ['2023arXiv230501150B',
#      'arXiv:2305.01150',
#      '10.48550/arXiv.2305.01150']},
#    {'bibcode': '2023arXiv230500831M',
#     'identifier': ['2023arXiv230500831M',
#      'arXiv:2305.00831',
#      '10.48550/arXiv.2305.00831']},
#    {'bibcode': '2023arXiv230501496H',
#     'identifier': ['arXiv:2305.01496',
#      '2023arXiv230501496H',
#      '10.48550/arXiv.2305.01496']},
#    {'bibcode': '2019MNRAS.489.1805H',
#     'identifier': ['10.1093/mnras/stz2251',
#      '2019MNRAS.tmp.2171H',
#      '2019MNRAS.489.1805H',
#      'arXiv:1711.10500',
#      '10.48550/arXiv.1711.10500',
#      '2017arXiv171110500H']},
#    {'bibcode': '2023JHEP...04..090K',
#     'identifier': ['arXiv:2302.02717',
#      '10.48550/arXiv.2302.02717',
#      '2023arXiv230202717K',
#      '2023JHEP...04..090K',
#      '10.1007/JHEP04(2023)090']},
#    {'bibcode': '2023arXiv230501446M',
#     'identifier': ['10.48550/arXiv.2305.01446',
#      'arXiv:2305.01446',
#      '2023arXiv230501446M']},
#    {'bibcode': '2016MNRAS.457...64I',
#     'identifier': ['2015arXiv151206191I',
#      'arXiv:1512.06191',
#      '10.1093/mnras/stv2957',
#      '2016MNRAS.457...64I',
#      '10.48550/arXiv.1512.06191']},
#    {'bibcode': '2002ASAJ..112..822R',
#     'identifier': ['10.1121/1.1497365', '2002ASAJ..112..822R']},
#    {'bibcode': '2023MNRAS.tmp.1121L',
#     'identifier': ['10.48550/arXiv.2301.06947',
#      '10.1093/mnras/stad1190',
#      '2023arXiv230106947L',
#      'arXiv:2301.06947',
#      '2023MNRAS.tmp.1121L']},
#    {'bibcode': '2022arXiv221011454S',
#     'identifier': ['arXiv:2210.11454',
#      '2022arXiv221011454S',
#      '10.48550/arXiv.2210.11454']},
#    {'bibcode': '2023arXiv230501607C',
#     'identifier': ['arXiv:2305.01607',
#      '2023arXiv230501607C',
#      '10.48550/arXiv.2305.01607']},
#    {'bibcode': '2023AdPhX...802331L',
#     'identifier': ['10.48550/arXiv.2206.15075',
#      '2023AdPhX...802331L',
#      '2022arXiv220615075L',
#      '10.1080/23746149.2023.2202331',
#      'arXiv:2206.15075']},
#    {'bibcode': '2023MNRAS.521..743P',
#     'identifier': ['10.1093/mnras/stad562',
#      '2023MNRAS.tmp..542P',
#      '2022arXiv221211817P',
#      'arXiv:2212.11817',
#      '2023MNRAS.521..743P',
#      '10.48550/arXiv.2212.11817']},
#    {'bibcode': '2023MNRAS.tmp.1128Q',
#     'identifier': ['10.48550/arXiv.2301.11854',
#      '2023MNRAS.tmp.1128Q',
#      '10.1093/mnras/stad1174',
#      '2023arXiv230111854Q',
#      'arXiv:2301.11854']},
#    {'bibcode': '2023PhRvD.107b3022C',
#     'identifier': ['10.48550/arXiv.2101.10370',
#      '10.1103/PhysRevD.107.023022',
#      '2023PhRvD.107b3022C',
#      '2021arXiv210110370C',
#      'arXiv:2101.10370']},
#    {'bibcode': '2023arXiv230214149W',
#     'identifier': ['arXiv:2302.14149',
#      '2023arXiv230214149W',
#      '10.48550/arXiv.2302.14149']},
#    {'bibcode': '2023arXiv230501383B',
#     'identifier': ['2023arXiv230501383B',
#      'arXiv:2305.01383',
#      '10.48550/arXiv.2305.01383']},
#    {'bibcode': '2023arXiv230412261R',
#     'identifier': ['2023arXiv230412261R',
#      '10.48550/arXiv.2304.12261',
#      'arXiv:2304.12261']},
#    {'bibcode': '1999EnST...33.3100W',
#     'identifier': ['10.1021/es990031y', '1999EnST...33.3100W']},
#    {'bibcode': '2014EnST...48.9325M',
#     'identifier': ['2014EnST...48.9325M', '10.1021/es5017894']},
#    {'bibcode': '1989QuRes..31..151D',
#     'identifier': ['10.1016/0033-5894(89)90004-5', '1989QuRes..31..151D']},
#    {'bibcode': '2022arXiv221201199S',
#     'identifier': ['10.48550/arXiv.2212.01199',
#      '2022arXiv221201199S',
#      'arXiv:2212.01199']},
#    {'bibcode': '2015NanoL..15.6862L',
#     'identifier': ['10.1021/acs.nanolett.5b02743', '2015NanoL..15.6862L']},
#    {'bibcode': '2002MarMP..46..387S',
#     'identifier': ['10.1016/S0377-8398(02)00082-8', '2002MarMP..46..387S']},
#    {'bibcode': '2015EnST...4913798W',
#     'identifier': ['2015EnST...4913798W', '10.1021/acs.est.5b00525']},
#    {'bibcode': '2012EnST...46.6252D',
#     'identifier': ['10.1021/es3006942', '2012EnST...46.6252D']},
#    {'bibcode': '2016EnST...5010308R',
#     'identifier': ['2016EnST...5010308R', '10.1021/acs.est.6b03338']},
#    {'bibcode': '2011EnST...45.6366E',
#     'identifier': ['2011EnST...45.6366E', '10.1021/es2013038']},
#    {'bibcode': '2018NanoL..18.5974L',
#     'identifier': ['10.1021/acs.nanolett.8b02806', '2018NanoL..18.5974L']},
#    {'bibcode': '2019EnST...5311170L',
#     'identifier': ['2019EnST...5311170L', '10.1021/acs.est.9b02462']},
#    {'bibcode': '2014EnST...48.8936B',
#     'identifier': ['10.1021/es500130g', '2014EnST...48.8936B']},
#    {'bibcode': '2003GSAB..115..899D',
#     'identifier': ['2003GSAB..115..899D', '10.1130/B25267.1']},
#    {'bibcode': '2002Geo....30..355W',
#     'identifier': ['10.1130/0091-7613(2002)030<0355:SCPOHW>2.0.CO2',
#      '2002Geo....30..355W']},
#    {'bibcode': '1995JAtC...22..319S',
#     'identifier': ['1995JAtC...22..319S', '10.1007/BF00696641']},
#    {'bibcode': '2002JPet...43...17S',
#     'identifier': ['10.1093/petrology/43.1.17', '2002JPet...43...17S']},
#    {'bibcode': '2006JVSTA..24.2025K',
#     'identifier': ['10.1116/1.2345645', '2006JVSTA..24.2025K']},
#    {'bibcode': '1987WASP...34..145B',
#     'identifier': ['1987WASP...34..145B', '10.1007/BF00184757']},
#    {'bibcode': '2015EnST...49.7754M',
#     'identifier': ['2015EnST...49.7754M', '10.1021/acs.est.5b00885']},
#    {'bibcode': '1993GeoRu..82..148S',
#     'identifier': ['1993GeoRu..82..148S', '10.1007/BF00563277']},
#    {'bibcode': '2017NanoL..17.5020I',
#     'identifier': ['10.1021/acs.nanolett.7b02248', '2017NanoL..17.5020I']},
#    {'bibcode': '1996JVSTA..14...56S',
#     'identifier': ['1996JVSTA..14...56S',
#      '10.1116/1.579880',
#      '1996JVST...14...56S']},
#    {'bibcode': '2002ApGC...17..855B',
#     'identifier': ['2002ApGC...17..855B', '10.1016/S0883-2927(01)00123-8']},
#    {'bibcode': '2015EnST...4910482V',
#     'identifier': ['10.1021/acs.est.5b02076', '2015EnST...4910482V']},
#    {'bibcode': '2015EnST...4911622S',
#     'identifier': ['2015EnST...4911622S', '10.1021/acs.est.5b01215']},
#    {'bibcode': '1985JVSTA...3..303J',
#     'identifier': ['10.1116/1.573255',
#      '1985JVST....3..303J',
#      '1985JVSTA...3..303J']},
#    {'bibcode': '2002PPP...182..221B',
#     'identifier': ['10.1016/S0031-0182(01)00497-7', '2002PPP...182..221B']},
#    {'bibcode': '2016JLwT...34..525D',
#     'identifier': ['2016JLwT...34..525D', '10.1109/JLT.2015.2480798']},
#    {'bibcode': '2019EnST...5310676L',
#     'identifier': ['2019EnST...5310676L', '10.1021/acs.est.9b02422']},
#    {'bibcode': '2011EnST...45.2562H',
#     'identifier': ['10.1021/es103300g', '2011EnST...45.2562H']},
#    ...]}}

# %%
'arXiv:2302.07880'[:6]
# Out:
# 'arXiv:'

# %% [markdown]
# ## arXiv

# %%
start_day = "01"
start_month = "02"
start_year = "2023"

end_day = "02"
end_month = "02"
end_year = "2023"

start =  f"{start_year}{start_month}{start_day}" #start_date.strftime("%Y%m%d")
end = f"{end_year}{end_month}{end_day}" #end_date.strftime("%Y%m%d")
range_str = f"[{start}000000+TO+{end}000000]"
range_query = f"lastUpdatedDate:{range_str}"
# range_query = f"submittedDate:{range_str}"

base_url = "http://export.arxiv.org/api/query?"
full_query = f"search_query=%28astro-ph.GA+OR+astro-ph.CO+OR+astro-ph.EP+OR+astro-ph.HE+OR+astro-ph.IM+OR+astro-ph.SR%29+AND+{range_query}&max_results={9999}"
url = base_url + full_query

response = urlopen(url).read()
feed = feedparser.parse(response)
# print(feed)

api_arxiv_titles = [e.title_detail["value"] for e in feed.entries]
api_arxiv_ids = [e.id.split("/")[-1] for e in feed.entries]
api_arxiv_ids = [re.sub("v\d", "", id_) for id_ in api_arxiv_ids]

print(len(api_arxiv_titles))
# Out:
# {'bozo': False, 'entries': [{'id': 'http://arxiv.org/abs/2302.01293v1', 'guidislink': True, 'link': 'http://arxiv.org/abs/2302.01293v1', 'updated': '2023-02-01T02:09:03Z', 'updated_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=1, tm_hour=2, tm_min=9, tm_sec=3, tm_wday=2, tm_yday=32, tm_isdst=0), 'published': '2023-02-01T02:09:03Z', 'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=1, tm_hour=2, tm_min=9, tm_sec=3, tm_wday=2, tm_yday=32, tm_isdst=0), 'title': 'QLP Data Release Notes 003: GPU-based Transit Search', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'QLP Data Release Notes 003: GPU-based Transit Search'}, 'summary': 'The Quick-Look Pipeline (QLP; Huang et al. 2020, Kunimoto et al. 2021 and\nreferences therein) searches for transit signals in the multi-sector light\ncurves of several hundreds of thousand stars observed by TESS every 27.4-day\nsector. The computational expense of the planet search has grown considerably\nover time, especially as the TESS observing baseline continues to increase in\nthe second Extended Mission. Starting in Sector 59, QLP has switched to a\nsignificantly faster GPU-based transit search capable of searching an entire\nsector in only ~1 day. We describe its implementation and performance.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'The Quick-Look Pipeline (QLP; Huang et al. 2020, Kunimoto et al. 2021 and\nreferences therein) searches for transit signals in the multi-sector light\ncurves of several hundreds of thousand stars observed by TESS every 27.4-day\nsector. The computational expense of the planet search has grown considerably\nover time, especially as the TESS observing baseline continues to increase in\nthe second Extended Mission. Starting in Sector 59, QLP has switched to a\nsignificantly faster GPU-based transit search capable of searching an entire\nsector in only ~1 day. We describe its implementation and performance.'}, 'authors': [{'name': 'Michelle Kunimoto'}, {'name': 'Evan Tey'}, {'name': 'Willie Fong'}, {'name': 'Katharine Hesse'}, {'name': 'Glen Petitpas'}, {'name': 'Avi Shporer'}], 'author_detail': {'name': 'Avi Shporer'}, 'author': 'Avi Shporer', 'arxiv_comment': '2 pages', 'links': [{'href': 'http://arxiv.org/abs/2302.01293v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/2302.01293v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'astro-ph.EP', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'astro-ph.EP', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'astro-ph.IM', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'astro-ph.SR', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}]}, {'id': 'http://arxiv.org/abs/2302.00322v1', 'guidislink': True, 'link': 'http://arxiv.org/abs/2302.00322v1', 'updated': '2023-02-01T08:57:43Z', 'updated_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=1, tm_hour=8, tm_min=57, tm_sec=43, tm_wday=2, tm_yday=32, tm_isdst=0), 'published': '2023-02-01T08:57:43Z', 'published_parsed': time.struct_time(tm_year=2023, tm_mon=2, tm_mday=1, tm_hour=8, tm_min=57, tm_sec=43, tm_wday=2, tm_yday=32, tm_isdst=0), 'title': 'First measurements of periodicities and anisotropies of cosmic ray flux\n  observed with a water-Cherenkov detector at the Marambio Antarctic base', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'First measurements of periodicities and anisotropies of cosmic ray flux\n  observed with a water-Cherenkov detector at the Marambio Antarctic base'}, 'summary': "A new water-Cherenkov radiation detector, located at the Argentine Marambio\nAntarctic Base (64.24S-56.62W), has been monitoring the variability of galactic\ncosmic ray (GCR) flux since 2019. One of the main aims is to provide\nexperimental data necessary to study interplanetary transport of GCRs during\n ...
# 83

# %%
range_query
# Out:
# 'lastUpdatedDate:[202321000000+TO+2023228000000]'

# %%
api_arxiv_ids
# Out:
# ['2301.05335',
#  '2304.09903',
#  '2304.09905',
#  '2304.09192',
#  '2304.07446',
#  '2304.09210',
#  '2304.09817',
#  '2304.09924',
#  '2211.13576',
#  '2304.09209',
#  '2304.09890',
#  '2304.09311',
#  '2304.09794',
#  '2304.08824',
#  '2304.09368',
#  '2205.07929',
#  '2304.09140',
#  '2206.10169',
#  '2209.11078',
#  '2304.09142',
#  '2304.09474',
#  '2304.09508',
#  '2304.09204',
#  '2304.09882',
#  '2301.01312',
#  '2304.08827',
#  '2304.09350',
#  '2210.08010',
#  '2304.08839',
#  '2304.07864',
#  '2304.07962',
#  '2304.08668',
#  '2304.05924',
#  '2304.09549',
#  '2304.09977',
#  '2304.09896',
#  '2304.08898',
#  '2304.09450',
#  '2304.09878',
#  '2205.07892',
#  '2210.11622',
#  '2304.09060',
#  '2304.09396',
#  '2304.09435',
#  '2304.09816',
#  '2304.09968',
#  '2304.09220',
#  '2304.09786',
#  '2304.09942',
#  '2304.09472',
#  '2304.09129',
#  '2211.00205',
#  '2304.09222',
#  '2304.09888',
#  '2304.09894',
#  '2303.16712',
#  '2212.13454',
#  '2304.09713',
#  '2212.00839',
#  '2304.09829',
#  '2209.07693',
#  '2204.06020',
#  '2304.08995',
#  '2304.09529',
#  '2304.09539',
#  '2304.08690',
#  '2304.09150',
#  '2304.08828',
#  '2304.09614',
#  '2304.08771',
#  '2304.09038',
#  '2304.09215',
#  '2304.09309',
#  '2304.09136',
#  '2304.09881',
#  '1311.6118',
#  '2301.02406',
#  '2301.06328',
#  '2301.10740',
#  '2304.01249',
#  '2304.09191',
#  '2304.09193',
#  '2304.09766',
#  '2304.09810',
#  '2301.07975',
#  '2303.16231',
#  '2304.08726',
#  '2304.08816',
#  '2304.09051',
#  '2304.09122',
#  '2304.09935',
#  '2203.01947',
#  '2304.09219',
#  '2103.00603',
#  '2210.12264',
#  '2210.14234',
#  '2304.09169',
#  '2304.09256',
#  '2304.09261',
#  '2304.09392',
#  '2304.09425',
#  '2304.09641',
#  '2304.09897',
#  '2304.09898',
#  '2304.09189',
#  '2210.02556',
#  '1211.5415',
#  '2010.15986',
#  '2303.00639',
#  '2304.02028',
#  '2304.08731',
#  '2304.09035',
#  '2304.09041',
#  '2304.09198',
#  '2304.09880',
#  '2304.09959',
#  '2210.00106',
#  '2302.12527',
#  '2304.09295',
#  '2303.00060',
#  '2304.08725',
#  '2210.14244',
#  '2301.09731',
#  '2304.02452',
#  '2304.06117',
#  '2304.08810',
#  '2304.08986',
#  '2304.09196',
#  '2304.09199',
#  '2304.09202',
#  '2304.09284',
#  '2304.09519',
#  '2304.09879',
#  '2304.09901',
#  '2304.09904',
#  '2304.09967',
#  '2107.03404',
#  '2207.11308',
#  '2209.02597',
#  '2302.10542',
#  '2304.08776',
#  '2304.09025',
#  '2304.09984',
#  '2207.10520',
#  '2209.07187',
#  '2304.09166',
#  '2304.09895',
#  '2210.00031',
#  '2301.00870',
#  '2304.08888',
#  '2304.09428',
#  '2304.09541',
#  '2211.16857',
#  '2304.09098',
#  '2304.09002',
#  '2304.09206',
#  '2304.09795',
#  '2304.09832',
#  '2304.09964',
#  '2212.04429',
#  '2304.09194',
#  '2304.09205',
#  '2202.13186']

# %%
for e in feed.entries:
    print(e.title)
    break
# Out:
# HST Low Resolution Stellar Library

# %%
n = 0
for title in api_arxiv_titles:
    print(title)
    n += 1
        
print(n)

# %%
directory = ".//data//arxiv emails//042023//"

with open(f"{directory}email.txt", 'r') as f:
    file_content = f.read()
    
email_arxiv_ids = re.findall(r'arXiv:\d{4}\.\d{5}', file_content) # looks like 'arXiv:2303.11347'
print(len(email_arxiv_ids))

email_arxiv_ids = [s[6:] for s in email_arxiv_ids]
# Out:
# Checking 88 papers

# %%
n = 0
for id_ in email_arxiv_ids:
    if id_ not in api_arxiv_ids:
        print(id_)
        n += 1
print(n)
# Out:
# 1609.06324
# 2301.06432
# 2304.07364
# 2102.12495
# 4

# %%
n = 0
for id_, title in zip(api_arxiv_ids, api_arxiv_titles):
    if id_ not in email_arxiv_ids:
        print(id_, title)
        n += 1
print(n)
# Out:
# 2304.07446 Evidence for Misalignment Between Debris Disks and Their Host Stars
# 2304.08824 A Dark Matter Probe in Accreting Pulsar-Black Hole Binaries
# 2205.07929 Dusty, Self-obscured Transients from Stellar Coalescence
# 2304.09140 A Sun-like star orbiting a boson star
# 2304.09142 Cosmology with Galaxy Cluster Properties using Machine Learning
# 2304.08827 The evolutionary route to form planetary nebulae with central neutron
#   star - white dwarf binaries
# 2304.08839 The progenitors of Type Ia supernovae with asymptotic giant branch
#   donors
# 2304.07864 Radio AGN Selection and Characterization in Three Deep-Drilling Fields
#   of the Vera C. Rubin Observatory Legacy Survey of Space and Time
# 2304.08668 Emerging planetary nebulae within 3D spiral patterns
# 2304.08898 Galaxy pairs in The Three Hundred simulations II: studying bound ones
#   and identifying them via machine learning
# 2304.06529 Cosmological application of the lens-redshift probability distribution
#   with improved galaxy-scale gravitational lensing sample
# 2210.11622 X-Ray Luminous Supernovae: Threats to Terrestrial Biospheres
# 2304.09060 Mass measurements and 3D orbital geometry of PSR J1933$-$6211
# 2304.09129 First constraints of dense molecular gas at z~7.5 from the quasar
#   Pōniuā'ena
# 2303.16712 Near-IR and optical radial velocities of the active M dwarf star Gl 388
#   (AD Leo) with SPIRou at CFHT and SOPHIE at OHP: A 2.23 day rotation period
#   and no evidence for a corotating planet
# 2212.00839 Expected Fragment Distribution from the First Interstellar Meteor CNEOS
#   2014-01-08
# 2209.07693 Gravitational waves from primordial scalar and tensor perturbations
# 2204.06020 Localizing Sources of Variability in Crowded TESS Photometry
# 2304.08995 The Simons Observatory: Beam characterization for the Small Aperture
#   Telescopes
# 2304.08690 Surface pressure impact on nitrogen-dominated USP super-Earth
#   atmospheres
# 2304.09150 Constraints on Europa's water group torus from HST/COS observations
# 2304.08828 Tidal disruption events and quasi periodic eruptions
# 2304.08771 MHD study of extreme space weather conditions for exoplanets with
#   Earth-like magnetospheres: On habitability conditions and radio-emission
# 2304.09038 Secular orbital dynamics of the innermost exoplanet of the
#   $\upsilon$-Andromedæ system
# 2304.09136 The effect of the LMC on the Milky Way system
# 1311.6118 A Large Scale Pattern from Optical Quasar Polarization Vectors
# 2301.06328 $H_0$ Tension in Torsion-based Modified Gravity
# 2304.01249 On the primordial black hole formation in hybrid inflation
# 2304.08666 Identification of Extended Emission Gamma-Ray-Bursts Candidates using
#   Machine Learning
# 2304.08726 Two-injection scenario for the hard X-ray excess observed in Mrk 421
# 2304.08816 X-ray flashes from the low-mass X-ray binary IGR J17407-2808
# 2304.09051 Possible origin of AT2021any: a failed GRB from a structured jet
# 2304.09122 Optical darkness in short-duration $γ$-ray bursts
# 2203.01947 Tidal Wave Breaking in the Eccentric Lead-In to Mass Transfer and Common
#   Envelope Phases
# 2210.12264 A machine learning approach to assessing the presence of substructure in
#   quasar host galaxies using the Hyper Suprime-Cam Subaru Strategic Program
# 2210.14234 A novel approach to correcting $T_e$-based mass-metallicity relations
# 2304.09169 The role of mass and environment in the build up of the quenched galaxy
#   population since cosmic noon
# 2210.02556 A unified model of inflation and dark energy based on the holographic
#   spacetime foam
# 1211.5415 Generalized Entropy Approach for Conserved Systems with Finite vs
#   Infinite Entities: Insights into Non-Gaussian and Non-Chi-Square
#   Distributions using Havrda-Charvát-Tsallis Entropy vs Gaussian
#   Distributions via Boltzmann-Shannon Entropy
# 2303.00639 Numerical Discreteness Errors in Multi-Species Cosmological N-body
#   Simulations
# 2304.08731 The impact of halo concentration on the Sunyaev Zel'dovich effect signal
#   from massive galaxy clusters
# 2304.09035 Evolution of matter and galaxy clustering in cosmological hydrodynamical
#   simulations
# 2304.09041 Joint measurement of the galaxy cluster pressure profile with Planck and
#   SPT-SZ
# 2210.00106 A broad survey of spectro-temporal properties from FRB 20121102A
# 2304.08725 Ultra-high-resolution Observations of Persistent Null-point Reconnection
#   in the Solar Corona
# 2210.14244 Bars and boxy/peanut bulges in thin and thick discs. II. Can bars form
#   in hot thick discs?
# 2304.06117 WISDOM project -- XIV. SMBH mass in the early-type galaxies NGC0612,
#   NGC1574, and NGC4261 from CO dynamical modelling
# 2304.08810 Physical cool-core condensation radius in massive galaxy clusters
# 2304.08986 Star formation in the dwarf Seyfert galaxy NGC 4395: Evidence for both
#   AGN and SNe feedback?
# 2107.03404 Equatorial timelike circular orbits around generic ultracompact objects
# 2209.02597 Synchrotron radiation by slowly rotating fermions
# 2304.08676 Trajectories of astroparticles in pseudo-Finsler spacetime with the most
#   general modified dispersion
# 2304.08776 Hot and highly magnetized neutron star matter properties with Skyrme
#   interactions
# 2304.09025 Tests of modified gravitational wave propagations with gravitational
#   waves
# 2209.07187 Primordial non-Gaussianity with Angular correlation function: Integral
#   constraint and validation for DES
# 2304.09166 A Cross-Internal Linear Combination Approach to Probe the Secondary CMB
#   Anisotropies: Kinematic Sunyaev-Zel{'}dovich Effect and CMB Lensing
# 2301.00870 Enhanced prospects for direct detection of inelastic dark matter from a
#   non-galactic diffuse component
# 2304.08874 Anisotropic power-law inflation for a generalized model of two scalar
#   and two vector fields
# 2304.08888 LIGO-VIRGO constraints on dark matter and leptogenesis triggered by a
#   first order phase transition at high scale
# 2304.09098 On the seed population of solar energetic particles in the inner
#   heliosphere
# 2304.09002 Cosmo-tomography toward PKS1830-211: Variability of the quasar and of
#   its foreground molecular absorption monitored with ALMA
# 61
