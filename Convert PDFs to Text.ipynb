# %%
import PyPDF2
import pandas as pd
import os
import warnings
import numpy as np
import string
import matplotlib.pyplot as plt

# %%
# warnings.filterwarnings("ignore", category=PyPDF2.errors.PdfReadWarning)
warnings.filterwarnings('ignore')

# %%
completed_ea_bibs = []
completed_ea_text = []
with open('.//data//ea_papers_text.txt', 'r', encoding="utf-8") as f:
    for line in f:
        bib = line.split(",")[0].strip()
        text = line.split(",")[1].strip()
        completed_ea_bibs.append(bib)
        completed_ea_text.append(text)
len(completed_ea_bibs)
# Out:
# 3538

# %%
unique_inds = np.unique(completed_ea_bibs, return_index=True)[1]
completed_ea_bibs = np.array(completed_ea_bibs)[unique_inds]
completed_ea_text = np.array(completed_ea_text)[unique_inds]
len(completed_ea_bibs)
# Out:
# 3538

# %%
# directory = ".//data//EA papers//"
# files = os.listdir(directory)
# print(len(files))
# print(len(np.unique(files)))

# for filename in files:
#     # filename ends in .pdf, bibcodes in completed_ea_files do not
#     if filename[:-4] in completed_ea_bibs:
#         continue
        
#     print(filename)
    
#     try:
#         reader = PyPDF2.PdfReader(directory+filename) # EOF error when file is corrupt
#     except:
#         with open('bad_ea_papers.txt', 'a', encoding="utf-8") as f:
#             f.write(f"{filename[:-4]}\n")
#         continue
        
#     paper_text = ""
#     pages_good = True
#     for page in reader.pages:
#         if pages_good:
#             try:
#                 text = page.extract_text() # grabs file name if text is nonselectable
#             except:
#                 pages_good = False
#                 continue
            
#             if text in filename:
#                 pages_good = False
                
#             paper_text += text
            
#         else:
#             paper_text = ""
#             break
    
#     if len(paper_text) > 0:
#         paper_text = paper_text.replace('\n', '').replace("\r", "")
#         for punct in string.punctuation:
#             paper_text = paper_text.replace(punct, "")
#         paper_text = paper_text.lower()
        
#         with open('ea_papers_text.txt', 'a', encoding="utf-8") as f:
#             f.write(f"{filename[:-4]},{paper_text}\n")
#     else:
#         with open('bad_ea_papers.txt', 'a', encoding="utf-8") as f:
#             f.write(f"{filename[:-4]}\n")
# Out:
# 3986
# 3986
# 1776QB65.F5.........pdf
# 1886BD....C......0A.pdf
# 1892RNAO...16....1T.pdf
# 1895MmRAS..51..185D.pdf
# 1896AnCap...3....1G.pdf
# 1903BD....C......0A.pdf
# 1918AnHar..91....1C.pdf
# 1919VeHei...7...10W.pdf
# 1932ADS...C......0A.pdf
# 1932ngcd.book.....A.pdf
# 1941POMin...3....1L.pdf
# 1941POMin...3...33L.pdf
# 1944POMin...4....1L.pdf
# 1950Lalan1847....0B.pdf
# 1952GCTP..C......0J.pdf
# 1957LTT...C......0L.pdf
# 1964BS....C......OH.pdf
# 1966CoLPL...4...99J.pdf
# 1966JO.....49..139R.pdf
# 1969VeARI..22....1G.pdf
# 1971GCVS3.C......0K.pdf
# 1971LowPM.C......0G.pdf
# 1975ascp.book.....H.pdf
# 1975MSS...C01....0H.pdf
# 1976Ap&SS..44..479T.pdf
# 1978bsch.book.....B.pdf
# 1978MSS...C02....0H.pdf
# 1979A&AS...36...57B.pdf
# 1979lccs.book.....L.pdf
len(completed_non_ea_bibs)
# Out:
# 4025

# %%
unique_inds = np.unique(completed_non_ea_bibs, return_index=True)[1]
completed_non_ea_bibs = np.array(completed_non_ea_bibs)[unique_inds]
completed_non_ea_text = np.array(completed_non_ea_text)[unique_inds]
len(completed_non_ea_bibs)
# Out:
# 4025

# %%
# directory = ".//data//non-EA papers//"
# files = os.listdir(directory)
# print(len(files))
# print(len(np.unique(files)))

# for filename in files:
#     # filename ends in .pdf, bibcodes in completed_ea_files do not
#     if filename[:-4] in completed_non_ea_bibs:
#         continue
        
    
    
#     try:
#         reader = PyPDF2.PdfReader(directory+filename) # EOF error when file is corrupt
#     except:
#         with open('bad_non_ea_papers.txt', 'a', encoding="utf-8") as f:
#             f.write(f"{filename[:-4]}\n")
#         continue
        
#     paper_text = ""
#     pages_good = True
#     for page in reader.pages:
#         if pages_good:
#             try:
#                 text = page.extract_text() # grabs file name if text is nonselectable
#             except:
#                 pages_good = False
#                 continue
            
#             if text in filename:
#                 pages_good = False
                
#             paper_text += text
            
#         else:
#             paper_text = ""
#             break
    
#     if len(paper_text) > 0:
#         paper_text = paper_text.replace('\n', '').replace("\r", "")
#         for punct in string.punctuation:
#             paper_text = paper_text.replace(punct, "")
#         paper_text = paper_text.lower()
        
#         print(filename)
#         with open('non_ea_papers_text.txt', 'a', encoding="utf-8") as f:
#             f.write(f"{filename[:-4]},{paper_text}\n")
#     else:
#         with open('bad_non_ea_papers.txt', 'a', encoding="utf-8") as f:
#             f.write(f"{filename[:-4]}\n")
# Out:
# 7979
# 7979
#  impossible to decode XFormObject /Im3
#  impossible to decode XFormObject /Im4

# %%
checked_nonexoplanet_negative_bibcodes = []
with open('.//data//checked_nonexoplanet_negatives.txt', 'r') as f:
    for line in f:
        checked_nonexoplanet_negative_bibcodes.append(line.strip())
        
print(len(checked_nonexoplanet_negative_bibcodes))
# Out:
# 9202

# %%
unchecked_bib_inds = []
for i in range(len(completed_non_ea_bibs)):
    if completed_non_ea_bibs[i] not in checked_nonexoplanet_negative_bibcodes:
        unchecked_bib_inds.append(i)
        
print(len(unchecked_bib_inds))

completed_non_ea_bibs = np.delete(completed_non_ea_bibs, unchecked_bib_inds)
completed_non_ea_text = np.delete(completed_non_ea_text, unchecked_bib_inds)

len(completed_non_ea_bibs)
# Out:
# 36
# 3989

# %%
completed_non_ea_years = []
for i in completed_non_ea_bibs:
    completed_non_ea_years.append(int(i[:4]))

# %%
plt.hist(completed_non_ea_years, bins=20)
plt.title("Non-EA Papers")
plt.xlabel("Year")
plt.show()

# %%
completed_ea_years = []
for i in completed_ea_bibs:
    completed_ea_years.append(int(i[:4]))

# %%
plt.hist(completed_ea_years)
plt.title("EA Papers")
plt.xlabel("Year")
plt.show()

plt.hist(completed_ea_years, bins=50)
plt.title("EA Papers")
plt.xlabel("Year")
plt.xlim(2000,2023)
plt.show()

# %%
random_ind = np.random.choice(range(len(completed_non_ea_bibs)))
print(completed_non_ea_bibs[random_ind])
print(completed_non_ea_text[random_ind])
# Out:
# 2022ApJ...938L..17Y
# draft version september 8 2022typeset using l atextwocolumn style in aastex631early results from glassjwst v the rst restframe optical sizeluminosity relation of galaxies atz 7l yang 1t morishita 2n leethochawalit 3 4 5m castellano 6a calabr o 6t treu 7a bonchi6 8a fontana 6c mason 9 10e merlin 6d paris 6m trenti 3 4g robertsborsani 7m bradac 11 12e vanzella 13b vulcani 14d marchesini 15x ding 1t nanayakkara 16s birrer 17 18 19k glazebrook 16t jones 12k boyett 3 4p santini 20v strait 9 10and x wang21kavli institute for the physics and mathematics of the universe the university of tokyo kashiwa japan 27785832infrared processing and analysis center caltech 1200 e california blvd pasadena ca 91125 usa3school of physics university of melbourne parkville 3010 vic australia4arc centre of excellence for all sky astrophysics in 3 dimensions astro 3d australia5national astronomical research institute of thailand narit mae rim chiang mai 50180 thailand6inaf osservatorio astronomico di roma via frascati 33 00078 monteporzio catone rome italy7department of physics and astronomy university of california los angeles 430 portola plaza los angeles ca 90095 usa8asispace science data center via del politecnico i00133 roma italy9cosmic dawn center dawn denmark10niels bohr institute university of copenhagen jagtvej 128 dk2200 copenhagen n denmark11university of ljubljana department of mathematics and physics jadranska ulica 19 si1000 ljubljana slovenia12department of physics and astronomy university of california davis 1 shields avenue davis ca 95616 usa13inaf  oas osservatorio di astrosica e scienza dello spazio di bologna via gobetti 933 i40129 bologna italy14inaf osservatorio astronomico di padova vicolo dellosservatorio 5 35122 padova italy15department of physics and astronomy tufts university 574 boston ave medford ma 02155 usa16centre for astrophysics and supercomputing swinburne university of technology po box 218 hawthorn vic 3122 australia17kavli institute for particle astrophysics and cosmology and department of physics stanford university stanford ca 94305 usa18slac national accelerator laboratory menlo park ca 9402519department of physics and astronomy stony brook university stony brook ny 11794 usa20inaf  osservatorio astronomico di roma via di frascati 33 00078 monte porzio catone italyabstractwe present the rst restframe optical sizeluminosity relation of galaxies at z 7 using the nircamimaging data obtained by the glass james webb space telescope early release science glassjwsters program providing the deepest extragalactic data of the ers campaign our sampleconsist of 19 photometrically selected bright galaxies with mf444w278 at 7z 9 andmf444w282 atz915 we measure the size of the galaxies in 5 bands from the restframe optical  4800 ato the ultraviolet uv 1600 a based on the s ersic model and analyze the sizeluminosity relationas a function of wavelength remarkably the data quality of nircam imaging is sucient to probethe halflight radius redown to100 pc at z  7 given the limited sample size and magnituderange we rst x the slope to that observed for larger samples in restframe uv using hst samplesthe median size r0at the reference luminosity m 21 decreases slightly from restframe optical60080 pc to uv 450 130 pc we then ret the sizeluminosity relation allowing the slope tovary the slope is consistent with 02 for all bands except f150w where we nd a marginallysteeper slope of  053015 the steep uv slope is mainly driven by the smallest and faintestgalaxies if conrmed by larger samples it implies that the uv sizeluminosity relation breaks towardthe faint end as suggested by lensing studiescorresponding author lilan yanglilanyangipmujparxiv220713101v2  astrophga  7 sep 20222 yang et alkeywords galaxies evolution  galaxies fundamental parameters  galaxies highredshift  galaxiesstructure1introductionthe size of a galaxy is a fundamental observable quantity its evolution and scaling relation with other properties such as luminosity and s ...
